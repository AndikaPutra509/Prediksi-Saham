# %% [markdown]
# <a href="https://colab.research.google.com/github/AndikaPutra509/Prediksi-Saham/blob/main/Quant_Medallion_Style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""IDX Stock Scanner - Medallion Style (Swing + FGV) + Advanced Quant Models
================================================================================
VERSI 2.0 - INTEGRASI 7 MODEL KUANTITATIF DENGAN MITIGASI OVERFITTING
================================================================================

Model yang diintegrasikan:
1. Linear Regression (Ridge Regularization) - dengan cross-validation
2. Kalman Filter (simdkalman) - untuk semua 588 saham sekaligus
3. GARCH (arch) - dengan rolling window & stationary check
4. HMM (hmmlearn) - dengan BIC untuk pemilihan jumlah state otomatis
5. ARIMA (pmdarima) - dengan auto_arima & AIC minimization
6. Monte Carlo (NumPy vektorisasi) - bootstrap historical returns
7. Neural Network LSTM (TensorFlow) - dengan dropout, early stopping, batch norm

SEMUA MODEL MEMPROSES 588 SAHAM - OPTIMASI VIA VEKTORISASI & PARALELISASI
MITIGASI OVERFITTING: Walk-Forward Validation, Rolling Window, Regularisasi
================================================================================
"""

# =============================================================================
# 0. INSTALL LIBRARY TAMBAHAN (termasuk Alphalens dan model baru)
# =============================================================================
# !pip install -q ta
# !pip install -q mplfinance
# !pip install -q alphalens-reloaded
# !pip install -q seaborn
# !pip install -q statsmodels
# !pip install -q arch
# !pip install -q hmmlearn
# !pip install -q pmdarima
# !pip install -q pykalman
# !pip install -q simdkalman
# !pip install -q tensorflow
# !pip install -q scikit-learn
# !pip install -q yfinance
# !pip install -q tabulate
# !pip install -q vectorbt

# =============================================================================
# 1. DEPENDENCIES & IMPORTS
# =============================================================================
import mplfinance as mpf
import matplotlib.pyplot as plt
from google.colab import auth
from google.auth import default
import gspread
import yfinance as yf
import pandas as pd
import numpy as np
import warnings
from datetime import datetime, timedelta
import time
import pickle
import os
import json
from tabulate import tabulate
from collections import defaultdict
import logging
import random
from typing import Optional, Dict, List, Tuple, Union, Any
import hashlib
import math
import ta
import glob

# Model-specific imports
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from arch import arch_model
from hmmlearn import hmm
from pmdarima import auto_arima
import pykalman
import simdkalman
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2


# Matikan logging yang tidak perlu
logging.getLogger('yfinance').setLevel(logging.CRITICAL)
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

# Setup logging untuk error handling
logging.basicConfig(
    filename='scanner_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

print("✅ Dependencies imported")

# =============================================================================
# SET RANDOM SEED FOR REPRODUCIBILITY
# =============================================================================
import random
import numpy as np
import tensorflow as tf
import os

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# =============================================================================
# SUPPRESS UNWANTED WARNINGS (clean output)
# =============================================================================
import warnings
warnings.filterwarnings('ignore')

# Set logging level untuk library yang chatty
logging.getLogger('hmmlearn').setLevel(logging.ERROR)
logging.getLogger('pykalman').setLevel(logging.ERROR)
logging.getLogger('tensorflow').setLevel(logging.ERROR)
logging.getLogger('matplotlib').setLevel(logging.ERROR)

# =============================================================================
# 2. STOCK UNIVERSE (FULL) - TIDAK BERUBAH
# =============================================================================
STOCKBIT_UNIVERSE = [
    "AALI", "ABBA", "ABDA", "ABMM", "ACES", "ADES", "ADHI", "ADMF", "ADMG", "ADRO",
    "AGAR", "AGII", "AGRO", "AHAP", "AIMS", "AISA", "AKRA", "AKSI", "ALDO", "ALKA",
    "HUMI", "IBFN", "IBOS", "IBST", "ICBP", "ICON", "IDPR", "IFII", "IFSH", "IGAR",
    "IIKP", "IKAI", "IKAN", "IMAS", "IMJS", "IMPC", "INAF", "INAI", "INCF", "INCI",
    "INCO", "INDF", "INDS", "INDX", "INDY", "INET", "INKP", "INPC", "INPP", "INPS",
    "INRU", "INTA", "INTD", "INTP", "IPCC", "IPCM", "IPOL", "IRRA", "ISAT", "ISEA",
    "ISSP", "ITIC", "ITMG", "JAST", "JAWA", "JAYA", "JECC", "JEMB", "JFAS", "JGLE",
    "JHON", "JIHD", "JKON", "JKSW", "JMAS", "JPFA", "JPII", "JPUR", "JRPT", "JSKY",
    "JSMR", "JSPT", "JTNB", "KAEF", "KAQI", "KARW", "KBLI", "KBLM", "KBRT", "KBRI",
    "KDSI", "KDTN", "KEEN", "KETR", "KICI", "KIJA", "KINO", "KIOS", "KJEN", "KKGI",
    "KLBF", "KMTR", "KOBX", "KOIN", "KOLI", "KONI", "KOTA", "KPAL", "KPIG", "KRAS",
    "KREN", "KRYA", "KSEL", "KUAS", "KUIC", "KUVO", "LAND", "LAPD", "LATA", "LBAK",
    "LCGP", "LCKM", "LEAD", "LIFE", "LINK", "LION", "LISA", "LMAS", "LMPI", "LMSH",
    "LPCK", "LPGI", "LPIN", "LPKR", "LPLI", "LPPF", "LPPS", "LSIP", "LSPI", "LTLS",
    "LUCY", "MABA", "MABH", "MAGP", "MAIN", "MAMI", "MAPA", "MAPB", "MAPI", "MARA",
    "MASA", "MAYA", "MBAP", "MBCA", "MBMA", "MBSS", "MBTO", "MCAS", "MCPI", "MCOR",
    "MDIA", "MDKA", "MDKI", "MEDC", "MEDS", "MEGA", "MERK", "META", "MFIN", "MFMI",
    "MGLV", "MGNA", "MGRO", "MIDI", "MIKA", "MINA", "MIRA", "MITI", "MITT", "MKNT",
    "MKPI", "MLBI", "MLIA", "MLPL", "MLPT", "MLSL", "MMIX", "MMLP", "MNCN", "MOLI",
    "MPOW", "MPPA", "MPRO", "MPTJ", "MRAT", "MSIE", "MSIN", "MSKY", "MTDL", "MTFN",
    "MTLA", "MTPS", "MTSM", "MUDA", "MUTU", "MYOH", "MYOR", "MYRX", "MYSX", "NAGA",
    "NASI", "NATO", "NAYZ", "NCKL", "NELY", "NETV", "NFCX", "NICL", "NIKL", "NISP",
    "NITY", "NIYM", "NOBU", "NPGF", "NRCA", "NSSS", "NTBK", "NUSA", "NUSI", "OASA",
    "OCTN", "OKAS", "OMED", "ONIX", "OPMS", "ORNA", "OTBK", "PADA", "PADI", "PAMG",
    "PANR", "PANS", "PANU", "PAPA", "PASA", "PASS", "PBRX", "PBID", "PBSA", "PCAR",
    "PDES", "PDGD", "PDIN", "PEGE", "PGAS", "PGLI", "PGUN", "PICO", "PIDRA", "PJAA",
    "PKPK", "PLAN", "PLAS", "PLIN", "PMJS", "PMMP", "PNBN", "PNBS", "PNIN", "PNLF",
    "PNSE", "POLI", "POLL", "POLU", "POLY", "POOL", "PORT", "POWR", "PPGL", "PPRE",
    "PPRO", "PPSI", "PRAS", "PRDA", "PRIM", "PRIN", "PRLD", "PROD", "PROT", "PRTS",
    "PSAB", "PSBA", "PSDN", "PSGO", "PSKT", "PSSI", "PTBA", "PTDU", "PTIS", "PTMP",
    "PTPP", "PTPW", "PTRO", "PTSN", "PTSP", "PUDP", "PURA", "PURE", "PWON", "PYFA",
    "RACE", "RADIO", "RAFI", "RAJA", "RAKD", "RALS", "RANC", "RATU", "RBMS", "RDTX",
    "REAL", "RELI", "RIGS", "RIMO", "RISE", "RMBA", "RMKE", "ROCK", "RODA", "ROKI",
    "ROTI", "RRMI", "RUIS", "RUMI", "SABA", "SAFE", "SAME", "SAPX", "SARA", "SATO",
    "SBAT", "SBBP", "SBGA", "SBMA", "SBMF", "SCBD", "SCCC", "SCCO", "SCMA", "SCNP",
    "SDPC", "SDRA", "SEAN", "SECR", "SEMA", "SFAN", "SGER", "SGRO", "SHID", "SHIP",
    "SIDO", "SILO", "SIMA", "SIMP", "SIPD", "SIPO", "SKBM", "SKLT", "SKRN", "SLIS",
    "SMAR", "SMDR", "SMGR", "SMIL", "SMMT", "SMSM", "SMRA", "SNLK", "SNMS", "SOFA",
    "SONA", "SOSS", "SOUL", "SPMA", "SPMI", "SPNA", "SPRE", "SPTO", "SQBI", "SQMI",
    "SRAJ", "SRIL", "SRSN", "SSIA", "SSMS", "SSTM", "STAR", "STTP", "SUGI", "SULI",
    "SUPR", "SURI", "SWAT", "SWID", "TALD", "TAMA", "TAMU", "TAPG", "TARA", "TASP",
    "TATA", "TAXI", "TBIG", "TBLA", "TCID", "TDPM", "TELE", "TEMB", "TEMPO", "TIFA",
    "TIGA", "TINS", "TIRA", "TIRT", "TITA", "TKGA", "TKIM", "TLKM", "TMAS", "TMPO",
    "TMSH", "TOBA", "TOOL", "TOPS", "TOSK", "TOTL", "TOTO", "TOWR", "TPIA", "TPMA",
    "TRAM", "TRGU", "TRIO", "TRIS", "TRJA", "TRON", "TRST", "TRUB", "TRUK", "TRUS",
    "TSPC", "TUGU", "TURI", "TUVN", "TYRE", "UANG", "UCID", "UDIJ", "UFNX", "UGRO",
    "UJSN", "ULTJ", "UNIC", "UNIQ", "UNIT", "UNSP", "USFI", "VALU", "VICO", "VICI",
    "VIDI", "VISI", "VIVA", "VKTR", "VOKS", "VRNA", "VTNY", "WAPO", "WEGE", "WEHA",
    "WICO", "WIFI", "WIIM", "WINS", "WMUU", "WMPP", "WOOD", "WOWS", "WRKR", "WSBP",
    "WSKT", "WTON", "YELO", "YULE", "ZBRA", "ZINC", "ZONE"
]

# =============================================================================
# 3. SECTOR MAPPING (UPDATE 12 SEKTOR IDX-IC)
# =============================================================================
SECTOR_MAPPING = {
    'ENERGI': ['ADRO', 'BUMI', 'MEDC', 'PTBA', 'ITMG', 'AKRA', 'PGAS', 'ADMR', 'ABMM', 'RIGS', 'TPMA', 'BSSR', 'ENRG', 'DOID', 'BYAN', 'INDY', 'HRUM', 'ARTI', 'CITA', 'DKFT', 'MBMA', 'NIKL', 'RUIS', 'SGER', 'TOBA'],
SP', 'USFI', 'VALU', 'VICO', 'VICI', 'VIDI', 'VISI', 'VIVA', 'VKTR', 'VOKS', 'VRNA', 'VTNY', 'WAPO', 'WEGE', 'WEHA', 'WICO', 'WIFI', 'WIIM', 'WINS', 'WMUU', 'WMPP', 'WOOD', 'WOWS', 'WRKR', 'WSBP', 'WSKT', 'WTON', 'YELO', 'YULE', 'ZBRA', 'ZINC', 'ZONE'],
    'KONSUMEN_PRIMER': ['INDF', 'ICBP', 'UNVR', 'KLBF', 'MYOR', 'AMRT', 'CPIN', 'COCO', 'AISA', 'AYLS', 'BEEF', 'BISI', 'BOBA', 'BOLT', 'BREN', 'BRNA', 'BUVA', 'CAMP', 'CANI', 'CARS', 'CASA', 'CASS', 'CBDK', 'CBMF', 'CCSI', 'CDAX', 'CEKA', 'CENT', 'CFIN', 'CITA', 'CITY', 'CKRA', 'CLEO', 'CLPI', 'CMNP', 'CMPP', 'CMRY', 'CNKO', 'COAL', 'COCO', 'COWL', 'CPRO', 'CSAP', 'CSIS', 'CTBN', 'CTRA', 'CTTH', 'CUAN', 'DAAZ', 'DART', 'DASA', 'DAYA', 'DCII', 'DEGA', 'DEWA', 'DFAM', 'DGIK', 'DIGI', 'DILD', 'DIVA', 'DIVN', 'DKFT', 'DLTA', 'DMAS', 'DMND', 'DNAR', 'DNET', 'DNLS', 'DOID', 'DOOH', 'DPNS', 'DPUM', 'DSFI', 'DSNG', 'DSSA', 'DUCK', 'DUTI', 'DVLA', 'DYAN', 'EASI', 'EASY', 'EBMT', 'ECII', 'EDGE', 'EKAD', 'ELBA', 'ELSA', 'ELTY', 'EMBR', 'EMDE', 'EMTK', 'ENRG', 'ENVY', 'ENZO', 'EPAC', 'EPMT', 'ERAA', 'ERTX', 'ESSA', 'ESTA', 'ESTI', 'ETWA', 'EXCL', 'FAST', 'FASW', 'FILM', 'FISH', 'FITT', 'FKSF', 'FLMC', 'FMII', 'FORE', 'FORU', 'FORZ', 'FPNI', 'FREN', 'FUJI', 'FUTR', 'GAMA', 'GDST', 'GDYR', 'GEMS', 'GGRM', 'GGRP', 'GHON', 'GIDS', 'GJTL', 'GLVA', 'GMFI', 'GMTD', 'GOLD', 'GOOD', 'GOTO', 'GPRA', 'GRPH', 'GSMF', 'GTBO', 'GTRA', 'GTSI', 'GULA', 'GZCO', 'HADE', 'HDFA', 'HDIT', 'HEAL', 'HERO', 'HITS', 'HKMU', 'HMSP', 'HOKI', 'HOMI', 'HOPE', 'HOTL', 'HRME', 'HRTA', 'HRUM', 'HSBK', 'HSMP', 'HUMI', 'IBFN', 'IBOS', 'IBST', 'ICBP', 'ICON', 'IDPR', 'IFII', 'IFSH', 'IGAR', 'IIKP', 'IKAI', 'IKAN', 'IMAS', 'IMJS', 'IMPC', 'INAF', 'INAI', 'INCF', 'INCI', 'INCO', 'INDF', 'INDS', 'INDX', 'INDY', 'INET', 'INKP', 'INPC', 'INPP', 'INPS', 'INRU', 'INTA', 'INTD', 'INTP', 'IPCC', 'IPCM', 'IPOL', 'IRRA', 'ISAT', 'IS
PROT', 'PRTS', 'PSAB', 'PSBA', 'PSDN', 'PSGO', 'PSKT', 'PSSI', 'PTBA', 'PTDU', 'PTIS', 'PTMP', 'PTPP', 'PTPW', 'PTRO', 'PTSN', 'PTSP', 'PUDP', 'PURA', 'PURE', 'PWON', 'PYFA', 'RACE', 'RADIO', 'RAFI', 'RAJA', 'RAKD', 'RALS', 'RANC', 'RATU', 'RBMS', 'RDTX', 'REAL', 'RELI', 'RIGS', 'RIMO', 'RISE', 'RMBA', 'RMKE', 'ROCK', 'RODA', 'ROKI', 'ROTI', 'RRMI', 'RUIS', 'RUMI', 'SABA', 'SAFE', 'SAME', 'SAPX', 'SARA', 'SATO', 'SBAT', 'SBBP', 'SBGA', 'SBMA', 'SBMF', 'SCBD', 'SCCC', 'SCCO', 'SCMA', 'SCNP', 'SDPC', 'SDRA', 'SEAN', 'SECR', 'SEMA', 'SFAN', 'SGER', 'SGRO', 'SHID', 'SHIP', 'SIDO', 'SILO', 'SIMA', 'SIMP', 'SIPD', 'SIPO', 'SKBM', 'SKLT', 'SKRN', 'SLIS', 'SMAR', 'SMDR', 'SMGR', 'SMIL', 'SMMT', 'SMSM', 'SMRA', 'SNLK', 'SNMS', 'SOFA', 'SONA', 'SOSS', 'SOUL', 'SPMA', 'SPMI', 'SPNA', 'SPRE', 'SPTO', 'SQBI', 'SQMI', 'SRAJ', 'SRIL', 'SRSN', 'SSIA', 'SSMS', 'SSTM', 'STAR', 'STTP', 'SUGI', 'SULI', 'SUPR', 'SURI', 'SWAT', 'SWID', 'TALD', 'TAMA', 'TAMU', 'TAPG', 'TARA', 'TASP', 'TATA', 'TAXI', 'TBIG', 'TBLA', 'TCID', 'TDPM', 'TELE', 'TEMB', 'TEMPO', 'TIFA', 'TIGA', 'TINS', 'TIRA', 'TIRT', 'TITA', 'TKGA', 'TKIM', 'TLKM', 'TMAS', 'TMPO', 'TMSH', 'TOBA', 'TOOL', 'TOPS', 'TOSK', 'TOTL', 'TOTO', 'TOWR', 'TPIA', 'TPMA', 'TRAM', 'TRGU', 'TRIO', 'TRIS', 'TRJA', 'TRON', 'TRST', 'TRUB', 'TRUK', 'TRUS', 'TSPC', 'TUGU', 'TURI', 'TUVN', 'TYRE', 'UANG', 'UCID', 'UDIJ', 'UFNX', 'UGRO', 'UJSN', 'ULTJ', 'UNIC', 'UNIQ', 'UNIT', 'UNSP', 'USFI', 'VALU', 'VICO', 'VICI', 'VIDI', 'VISI', 'VIVA', 'VKTR', 'VOKS', 'VRNA', 'VTNY', 'WAPO', 'WEGE', 'WEHA', 'WICO', 'WIFI', 'WIIM', 'WINS', 'WMUU', 'WMPP', 'WOOD', 'WOWS', 'WRKR', 'WSBP', 'WSKT', 'WTON', 'YELO', 'YULE', 'ZBRA', 'ZINC', 'ZONE'],
    'KONSUMEN_NON_PRIMER': ['IMAS', 'MAPI', 'ACES', 'ERAA', 'MAPB', 'SONA', 'CSAP', 'MIDI', 'MFMI', 'AMRT', 'LPPF', 'RALS', 'JAST', 'MASA', 'PADA', 'PANS', 'SMSM', 'TRAM', 'UANG', 'VICI', 'VIVA', 'WICO', 'WINS'],
', 'TRUS', 'TSPC', 'TUGU', 'TURI', 'TUVN', 'TYRE', 'UANG', 'UCID', 'UDIJ', 'UFNX', 'UGRO', 'UJSN', 'ULTJ', 'UNIC', 'UNIQ', 'UNIT', 'UNSP', 'USFI', 'VALU', 'VICO', 'VICI', 'VIDI', 'VISI', 'VIVA', 'VKTR', 'VOKS', 'VRNA', 'VTNY', 'WAPO', 'WEGE', 'WEHA', 'WICO', 'WIFI', 'WIIM', 'WINS', 'WMUU', 'WMPP', 'WOOD', 'WOWS', 'WRKR', 'WSBP', 'WSKT', 'WTON', 'YELO', 'YULE', 'ZBRA', 'ZINC', 'ZONE']
}

def get_sector(symbol: str) -> str:
    """Get sector for a symbol"""
    for sector, stocks in SECTOR_MAPPING.items():
        if symbol in stocks:
            return sector
    return 'OTHER'

# =============================================================================
# 4. GLOBAL INDICES (TANPA SEASONALITY)
# =============================================================================
GLOBAL_INDICES = {
    "IHSG": {"ticker": "^JKSE", "nama": "Indeks Harga Saham Gabungan", "satuan": "poin"},
    "DOWJONES": {"ticker": "^DJI", "nama": "Dow Jones Industrial Average", "satuan": "poin"},
    "USDIDR": {"ticker": "IDR=X", "nama": "USD/IDR", "satuan": "Rp/USD"},
    "OIL": {"ticker": "CL=F", "nama": "Crude Oil WTI", "satuan": "USD/barel"},
    "GOLD": {"ticker": "GC=F", "nama": "Gold Futures", "satuan": "USD/ons"},
    "NIKKEI": {"ticker": "^N225", "nama": "Nikkei 225", "satuan": "poin"},
    "SHANGHAI": {"ticker": "000001.SS", "nama": "Shanghai Composite Index", "satuan": "poin"}
}

class GlobalIndicesFetcher:
    def __init__(self):
        self.data = {}
        self.prices = {}

    def fetch_all(self) -> None:
        print("\n" + "="*80)
        print("📡 FETCHING GLOBAL INDICES")
        print("="*80)
        end_date = datetime.now()
        start_date = end_date - timedelta(days=365*2)
        for name, config in GLOBAL_INDICES.items():
            ticker = config["ticker"]
            print(f"\n📊 {name}: {config['nama']} ({ticker})")
            try:
                df = yf.download(ticker, start=start_date.strftime("%Y-%m-%d"),
                                 end=end_date.strftime("%Y-%m-%d"), interval="1d",
                                 auto_adjust=True, progress=False, timeout=10)
                time.sleep(0.5)
                if df.empty or len(df) < 200:
                    self.prices[name] = 0.0
                    print(f"   ⚠️ Status: TIDAK TERSEDIA")
                else:
                    if isinstance(df.columns, pd.MultiIndex):
                        df.columns = df.columns.get_level_values(0)
                    close = df['Close'].values
                    current_price = float(close[-1])
                    self.data[name] = df
                    self.prices[name] = round(current_price, 2)
                    print(f"   ✅ Harga: {self.get_price_str(name)}")
            except Exception as e:
                self.prices[name] = 0.0
                print(f"   ❌ Error: {str(e)[:50]}")
        print("\n" + "="*80)

    def get_price_str(self, name: str) -> str:
        price = self.prices.get(name, 0)
        if price == 0:
            return "N/A"
        if name in ["IHSG", "DOWJONES", "NIKKEI", "SHANGHAI"]:
            return f"{price:,.2f}"
        elif name == "USDIDR":
            return f"Rp {price:,.0f}"
        elif name in ["OIL", "GOLD"]:
            return f"US$ {price:.2f}"
        return f"{price:.2f}"

# =============================================================================
# 5. DATA WAREHOUSE (HANYA HARGA, TANPA DIVIDEN & FUNDAMENTAL)
# =============================================================================
class DataWarehouse:
    def __init__(self, warehouse_dir: str = 'data_warehouse', min_days: int = 1000):
        self.warehouse_dir = warehouse_dir
        self.min_days = min_days
        os.makedirs(warehouse_dir, exist_ok=True)
        self.stats = {'total_symbols': 0, 'downloaded': 0, 'failed': 0, 'cached': 0, 'filtered_min_days': 0}

    def download_complete_history(self, symbols: List[str], start_date: str = '2006-01-01',
                                  end_date: str = '2026-12-31', force_refresh: bool = False) -> Dict[str, pd.DataFrame]:
        print("\n" + "="*80)
        print("🗄️ DATA WAREHOUSE - DOWNLOAD HISTORIS")
        print(f"Periode: {start_date} s.d. {end_date}")
        print(f"Total saham: {len(symbols)} | Minimal hari: {self.min_days}")
        print("="*80)
        results = {}
        self.stats['total_symbols'] = len(symbols)
        start_dt = pd.to_datetime(start_date)
        end_dt = pd.to_datetime(end_date)

        for i, symbol in enumerate(symbols):
            cache_file = f"{self.warehouse_dir}/{symbol}_full.parquet"
            if os.path.exists(cache_file) and not force_refresh:
                try:
                    df = pd.read_parquet(cache_file)
                    if len(df) >= self.min_days and df.index[0] <= start_dt and df.index[-1] >= end_dt:
                        results[symbol] = df
                        self.stats['cached'] += 1
                    else:
                        self.stats['filtered_min_days'] += 1
                    if (i+1) % 50 == 0:
                        print(f"   Progress: {i+1}/{len(symbols)} - {len(results)} dimuat (cache)")
                    continue
                except Exception:
                    pass
            try:
                ticker = f"{symbol}.JK"
                print(f"   Downloading {symbol} ({i+1}/{len(symbols)})...", end=" ")
                df = yf.download(ticker, start=start_date, end=end_date, interval="1d",
                                 auto_adjust=True, progress=False, timeout=30)
                time.sleep(0.5)
                if df.empty:
                    print("❌ GAGAL (data kosong)")
                    self.stats['failed'] += 1
                    continue
                if isinstance(df.columns, pd.MultiIndex):
                    df.columns = df.columns.get_level_values(0)
                if len(df) < self.min_days:
                    print(f"❌ GAGAL (hanya {len(df)} hari)")
                    self.stats['filtered_min_days'] += 1
                    continue
                df.to_parquet(cache_file)
                results[symbol] = df
                self.stats['downloaded'] += 1
                print(f"✅ {len(df)} hari")
            except Exception as e:
                print(f"❌ ERROR: {str(e)[:50]}")
                self.stats['failed'] += 1
                logger.error(f"Error downloading {symbol}: {str(e)}")
        print("\n" + "="*80)
        print(f"✅ Berhasil dimuat: {len(results)} saham (cache: {self.stats['cached']}, baru: {self.stats['downloaded']})")
        print(f"   Difilter (<{self.min_days} hari): {self.stats['filtered_min_days']} | Gagal: {self.stats['failed']}")
        return results

    def get_all_valid_symbols(self) -> List[str]:
        symbols = []
        for f in os.listdir(self.warehouse_dir):
            if f.endswith('_full.parquet'):
                symbol = f.replace('_full.parquet', '')
                try:
                    df = pd.read_parquet(os.path.join(self.warehouse_dir, f))
                    if len(df) >= self.min_days:
                        symbols.append(symbol)
                except Exception:
                    continue
        return symbols

    def get_data(self, symbol: str) -> Optional[pd.DataFrame]:
        cache_file = f"{self.warehouse_dir}/{symbol}_full.parquet"
        if not os.path.exists(cache_file):
            return None
        try:
            df = pd.read_parquet(cache_file)
            if len(df) >= self.min_days:
                return df
            return None
        except Exception:
            return None

# =============================================================================
# 6. UTILITY FUNCTIONS
# =============================================================================
def normalize_columns(df: pd.DataFrame) -> pd.DataFrame:
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

def calculate_spread_pct(df: pd.DataFrame) -> float:
    try:
        spread = ((df['High'] - df['Low']) / df['Close']).tail(10).mean() * 100
        return float(spread)
    except Exception:
        return 999.0

def get_support_resistance(df: pd.DataFrame, lookback: int = 60) -> Tuple[float, float]:
    if len(df) < lookback:
        recent = df.iloc[:-1] if len(df) > 1 else df
        support = recent['Low'].min()
        resistance = recent['High'].max()
    else:
        recent = df.tail(lookback+1).iloc[:-1]
        support = recent['Low'].min()
        resistance = recent['High'].max()
    return support, resistance

def validate_risk_reward(price: float, sl: float, tp: float, min_rr: float = 1.0) -> Tuple[bool, float, float, float]:
    if sl >= price or tp <= price:
        return False, 0, 0, 0
    risk = price - sl
    reward = tp - price
    if risk <= 0:
        return False, 0, 0, 0
    rr = reward / risk
    return rr >= min_rr, risk, reward, rr

# =============================================================================
# 7. MODAL ADAPTER (FILTER HARGA & TURNOVER)
# =============================================================================
class ModalAdapter:
    def __init__(self, modal: float, engine_type: str):
        self.modal = modal
        self.engine_type = engine_type
        if modal < 50000:
            self.kategori = "ULTRA_MIKRO"
        elif modal < 100000:
            self.kategori = "MIKRO"
        elif modal < 500000:
            self.kategori = "RETAIL"
        elif modal < 2000000:
            self.kategori = "MENENGAH"
        else:
            self.kategori = "BESAR"
        self.max_harga_beli = modal / 100
    def get_filter_harga(self) -> Tuple[float, float]:
        if self.kategori == "ULTRA_MIKRO":
            return 5, 500
        elif self.kategori == "MIKRO":
            return 5, 500
        elif self.kategori == "RETAIL":
            return 10, 1000
        elif self.kategori == "MENENGAH":
            return 30, 2000
        else:
            return 50, 5000
        max_price = min(max_price, self.max_harga_beli)
        return min_price, max_price
    def get_filter_turnover(self) -> Tuple[float, float]:
        if self.kategori == "ULTRA_MIKRO":
            return 20000, 50000
        elif self.kategori == "MIKRO":
            return 30000, 70000
        elif self.kategori == "RETAIL":
            return 150000, 200000
        elif self.kategori == "MENENGAH":
            return 500000, 1000000
        else:
            return 1000000, 3000000
    def get_filter_spread(self) -> float:
        return 8.0 if self.kategori in ["ULTRA_MIKRO", "MIKRO"] else 6.0 if self.kategori == "RETAIL" else 4.0
    def get_filter_min_history(self) -> int:
        return 20 if self.kategori in ["ULTRA_MIKRO", "MIKRO"] else 60 if self.kategori == "RETAIL" else 100
    def get_entry_tolerance(self) -> float:
        return 15.0 if self.kategori in ["ULTRA_MIKRO", "MIKRO"] else 10.0 if self.kategori == "RETAIL" else 7.0
    def get_trend_tolerance(self) -> float:
        return 0.85 if self.kategori in ["ULTRA_MIKRO", "MIKRO"] else 0.90 if self.kategori == "RETAIL" else 0.95

# =============================================================================
# 8. RISK MANAGER (DENGAN PARTIAL EXIT & TRAILING STOP)
# =============================================================================
class RiskManager:
    def __init__(self, modal: float, engine_type: str = 'swing'):
        self.modal = modal
        self.engine_type = engine_type
        self.risk_per_trade_pct = 1.0
        self.max_risk_portfolio_pct = 10.0
        self.max_positions = 10
        self.max_modal_per_position_pct = 90.0
        self.risk_per_trade_rp = modal * (self.risk_per_trade_pct / 100)
        self.max_risk_portfolio_rp = modal * (self.max_risk_portfolio_pct / 100)
        self.max_modal_per_position_rp = modal * (self.max_modal_per_position_pct / 100)
        self.current_positions = []
        self.current_risk_rp = 0.0
        self.current_modal_used_rp = 0.0
        self.trade_history = []
    def set_risk_multiplier(self, multiplier: float):
        """Sesuaikan risk per trade berdasarkan multiplier (0.5 = 50% dari normal)"""
        original_risk_pct = 1.0
        new_risk_pct = original_risk_pct * multiplier
        self.risk_per_trade_pct = new_risk_pct
        self.risk_per_trade_rp = self.modal * (new_risk_pct / 100)
        print(f"   Risk per trade disesuaikan: {original_risk_pct:.1f}% -> {new_risk_pct:.1f}% (multiplier {multiplier:.1f})")
    def calculate_atr_in_rupiah(self, df: pd.DataFrame, period: int = 14) -> float:
        try:
            high = df['High'].shift(1)
            low = df['Low'].shift(1)
            close = df['Close'].shift(1)
            tr1 = high - low
            tr2 = (high - close).abs()
            tr3 = (low - close).abs()
            tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
            atr = tr.rolling(window=period, min_periods=period).mean()
            valid_atr = atr.dropna()
            if len(valid_atr) == 0:
                current_price = float(df['Close'].iloc[-1])
                return current_price * 0.02
            atr_value = float(valid_atr.iloc[-1])
            current_price = float(df['Close'].iloc[-1])
            min_atr = current_price * 0.01
            atr_value = max(atr_value, min_atr)
            return atr_value
        except Exception:
            current_price = float(df['Close'].iloc[-1])
            return current_price * 0.02
    def calculate_lot(self, close: float, atr: float, symbol: str = None) -> Tuple[Optional[int], Optional[float], Optional[float]]:
        if atr <= 0 or close <= 0:
            return None, None, None
        risk_per_lot = atr * 100
        raw_lot = self.risk_per_trade_rp / risk_per_lot
        lot = int(raw_lot)
        if lot < 1:
            return None, None, None
        max_lot_by_modal = int(self.max_modal_per_position_rp / (close * 100))
        lot = min(lot, max_lot_by_modal)
        if lot < 1:
            return None, None, None
        cost = lot * 100 * close
        risk_amount = lot * risk_per_lot
        return lot, cost, risk_amount
    def can_add_position(self, risk_amount: float, cost: float = None) -> Tuple[bool, str]:
        if self.current_risk_rp + risk_amount > self.max_risk_portfolio_rp:
            return False, f"Portfolio risk limit: Rp {self.max_risk_portfolio_rp:,.0f}"
        if cost and self.current_modal_used_rp + cost > self.modal * 0.99:
            return False, f"Modal tidak cukup"
        if len(self.current_positions) >= self.max_positions:
            return False, f"Max positions ({self.max_positions}) reached"
        return True, "OK"
    def add_position(self, symbol: str, lot: int, entry_price: float,
                      risk_amount: float, cost: float,
                      stop_loss: float = None,
                      exit_plan: dict = None) -> None:
        pos = {
            'symbol': symbol,
            'lot': lot,
            'entry_price': entry_price,
            'risk_amount': risk_amount,
            'cost': cost,
            'entry_date': datetime.now(),
            'stop_loss': stop_loss if stop_loss else entry_price * 0.95,
            'remaining_lot': lot,
            'realized_pnl': 0.0,
            'exit_plan': exit_plan,
            'trailing_active': False,
            'highest_high': entry_price,
            'trail_stop_current': None
        }
        if exit_plan and 'trailing' in exit_plan:
            pos['trail_activation_price'] = exit_plan['trailing']['activation_price']
            pos['trail_distance_mult'] = exit_plan['trailing']['distance_mult']
        self.current_positions.append(pos)
        self.current_risk_rp += risk_amount
        self.current_modal_used_rp += cost
    def remove_position(self, symbol: str) -> None:
        for i, pos in enumerate(self.current_positions):
            if pos['symbol'] == symbol:
                self.current_risk_rp -= pos['risk_amount'] * (pos['remaining_lot'] / pos['lot'])
                self.current_modal_used_rp -= pos['cost'] * (pos['remaining_lot'] / pos['lot'])
                self.current_positions.pop(i)
                break
    def update_position(self, symbol: str, current_high: float, current_low: float,
                         current_price: float, atr: float) -> Dict:
        actions = []
        for pos in self.current_positions:
            if pos['symbol'] != symbol:
                continue
            if pos['remaining_lot'] <= 0:
                continue
            if pos['exit_plan'] and 'levels' in pos['exit_plan']:
                for level in pos['exit_plan']['levels']:
                    if level.get('executed', False):
                        continue
                    if current_high >= level['price']:
                        sell_lot = int(round(pos['lot'] * level['sell_pct'] / 100))
                        if sell_lot > 0 and sell_lot <= pos['remaining_lot']:
                            actions.append({
                                'sell_lot': sell_lot,
                                'price': level['price'],
                                'reason': f"TP_{level['price']}"
                            })
                            pos['remaining_lot'] -= sell_lot
                            level['executed'] = True
            if pos['remaining_lot'] > 0 and pos['exit_plan'] and 'trailing' in pos['exit_plan']:
                if current_high > pos['highest_high']:
                    pos['highest_high'] = current_high
                if not pos.get('trailing_active', False):
                    if current_high >= pos['exit_plan']['trailing']['activation_price']:
                        pos['trailing_active'] = True
                if pos.get('trailing_active', False):
                    trail_stop = pos['highest_high'] - (pos['trail_distance_mult'] * atr)
                    trail_stop = max(trail_stop, pos['stop_loss'])
                    fraction = 5 if current_price < 100 else 10 if current_price < 500 else 25
                    trail_stop = math.floor(trail_stop / fraction) * fraction
                    pos['trail_stop_current'] = trail_stop
                    if current_low <= trail_stop:
                        actions.append({
                            'sell_lot': pos['remaining_lot'],
                            'price': trail_stop,
                            'reason': 'TRAILING_STOP'
                        })
                        pos['remaining_lot'] = 0
            else:
                if current_low <= pos['stop_loss']:
                    actions.append({
                        'sell_lot': pos['remaining_lot'],
                        'price': pos['stop_loss'],
                        'reason': 'STOP_LOSS'
                    })
                    pos['remaining_lot'] = 0
        return {'actions': actions}
    def get_portfolio_risk_pct(self) -> float:
        total_risk = sum(p['risk_amount'] * (p['remaining_lot'] / p['lot']) for p in self.current_positions)
        return (total_risk / self.modal) * 100 if self.modal > 0 else 0
    def reset(self) -> None:
        self.current_positions = []
        self.current_risk_rp = 0.0
        self.current_modal_used_rp = 0.0
    def print_display(self):
        print("\n" + "-"*50)
        print("📊 RISK MANAGER STATUS")
        print("-"*50)
        print(f"Modal Total: Rp {self.modal:,.0f}")
        print(f"Risk per trade: {self.risk_per_trade_pct:.1f}% (Rp {self.risk_per_trade_rp:,.0f})")
        print(f"Max portfolio risk: {self.max_risk_portfolio_pct:.1f}% (Rp {self.max_risk_portfolio_rp:,.0f})")
        used_risk = sum(p['risk_amount'] * (p['remaining_lot'] / p['lot']) for p in self.current_positions)
        used_modal = sum(p['cost'] * (p['remaining_lot'] / p['lot']) for p in self.current_positions)
        print(f"Current used risk: Rp {used_risk:,.0f} ({self.get_portfolio_risk_pct():.1f}%)")
        print(f"Current used modal: Rp {used_modal:,.0f} ({(used_modal/self.modal)*100:.1f}%)")
        print(f"Remaining risk budget: Rp {self.max_risk_portfolio_rp - used_risk:,.0f}")
        print(f"Current positions: {len([p for p in self.current_positions if p['remaining_lot'] > 0])}")
        print("-"*50)

# =============================================================================
# 9. REALISTIC FEE CONFIG
# =============================================================================
class RealisticFeeConfig:
    BROKER_FEE_BUY = 0.0015
    BROKER_FEE_SELL = 0.0025
    VAT_RATE = 0.11
    TOTAL_FEE_BUY = BROKER_FEE_BUY * (1 + VAT_RATE)
    TOTAL_FEE_SELL = BROKER_FEE_SELL * (1 + VAT_RATE)

    def __init__(self, liquidity: str = 'medium'):
        self.liquidity = liquidity
        self.slippage = {'buy': 0.0002, 'sell': 0.0003}

    def calculate_buy_cost(self, price: float, lot: int) -> float:
        if price is None or lot is None or lot <= 0:
            return 0.0
        amount = price * 100 * lot
        return amount * self.TOTAL_FEE_BUY + amount * self.slippage['buy']

    def calculate_sell_cost(self, price: float, lot: int) -> float:
        if price is None or lot is None or lot <= 0:
            return 0.0
        amount = price * 100 * lot
        return amount * self.TOTAL_FEE_SELL + amount * self.slippage['sell']

    def calculate_round_trip(self, entry_price: float, exit_price: float, lot: int) -> Tuple[float, float, float]:
        if entry_price is None or lot is None or lot <= 0:
            return 0.0, 0.0, 0.0
        if exit_price is None:
            exit_price = entry_price
        buy_cost = self.calculate_buy_cost(entry_price, lot)
        sell_cost = self.calculate_sell_cost(exit_price, lot)
        total_fee = buy_cost + sell_cost
        buy_amount = entry_price * 100 * lot
        sell_amount = exit_price * 100 * lot
        gross_profit = sell_amount - buy_amount
        net_profit = gross_profit - total_fee
        net_return_pct = (net_profit / buy_amount) * 100 if buy_amount > 0 else 0
        return total_fee, net_profit, net_return_pct

# =============================================================================
# 10. SWING ENGINE (6 PATTERN + MEAN REVERSION + SCALING OUT + TRAILING STOP)
# =============================================================================
class SwingEngine:
    def __init__(self, config, global_fetcher):
        self.config = config
        self.global_fetcher = global_fetcher
        self.engine_type = 'swing'
        self.risk_manager = None
        self.modal_adapter = ModalAdapter(config.MODAL, self.engine_type)
    def set_risk_manager(self, risk_manager: RiskManager):
        self.risk_manager = risk_manager
    def calculate_features(self, df: pd.DataFrame) -> pd.DataFrame:
        out = df.copy()
        close = out['Close']
        high = out['High']
        low = out['Low']
        volume = out['Volume']
        # RSI
        delta = close.diff()
        gain = delta.clip(lower=0)
        loss = -delta.clip(upper=0)
        avg_gain = gain.rolling(14, min_periods=14).mean()
        avg_loss = loss.rolling(14, min_periods=14).mean()
        rs = avg_gain / (avg_loss + 1e-6)
        out['RSI'] = 100 - (100 / (1 + rs))
        # MA
        out['MA20'] = close.rolling(20, min_periods=20).mean()
        out['MA50'] = close.rolling(50, min_periods=50).mean()
        out['MA200'] = close.rolling(200, min_periods=200).mean()
        # Volume MA
        out['Volume_MA20'] = volume.rolling(20, min_periods=20).mean()
        out['Volume_Ratio'] = volume / (out['Volume_MA20'] + 1e-6)
        # MACD
        exp1 = close.ewm(span=12, adjust=False).mean()
        exp2 = close.ewm(span=26, adjust=False).mean()
        out['MACD'] = exp1 - exp2
        out['MACD_Signal'] = out['MACD'].ewm(span=9, adjust=False).mean()
        out['MACD_Hist'] = out['MACD'] - out['MACD_Signal']
        # ADX
        adx = ta.trend.ADXIndicator(high, low, close, window=14)
        out['ADX'] = adx.adx()
        out['DI+'] = adx.adx_pos()
        out['DI-'] = adx.adx_neg()
        # Bollinger Bands
        bb = ta.volatility.BollingerBands(close, window=20, window_dev=2)
        out['BB_Lower'] = bb.bollinger_lband()
        out['BB_Upper'] = bb.bollinger_hband()
        # Support/Resistance
        out['Swing_Low_20'] = low.rolling(20, min_periods=20).min()
        out['Swing_High_20'] = high.rolling(20, min_periods=20).max()
        return out.shift(1)
    def get_signal(self, symbol: str, df: pd.DataFrame):
        try:
            if df is None or len(df) < 200:
                return None
            df_feat = self.calculate_features(df)
            if df_feat is None or len(df_feat) < 200:
                return None
            latest = df_feat.iloc[-1]
            close = float(latest['Close'])
            if close <= 0:
                return None
            # Filter modal adapter
            min_price, max_price = self.modal_adapter.get_filter_harga()
            if close < min_price or close > max_price:
                return None
            min_turn, min_avg_turn = self.modal_adapter.get_filter_turnover()
            last_turnover = close * float(latest['Volume'])
            avg_turnover_20 = (df['Close'] * df['Volume']).tail(20).mean()
            if last_turnover < min_turn or avg_turnover_20 < min_avg_turn:
                return None
            spread = calculate_spread_pct(df)
            if spread > self.modal_adapter.get_filter_spread():
                return None
            # ATR
            atr = self.risk_manager.calculate_atr_in_rupiah(df) if self.risk_manager else close * 0.02
            atr_pct = (atr / close) * 100
            if atr_pct < 1.5:
                return None
            # Indikator
            rsi = float(latest['RSI']) if not pd.isna(latest['RSI']) else 50
            volume_ratio = float(latest['Volume_Ratio']) if not pd.isna(latest['Volume_Ratio']) else 1.0
            ma20 = float(latest['MA20']) if not pd.isna(latest['MA20']) else close
            ma50 = float(latest['MA50']) if not pd.isna(latest['MA50']) else close
            ma200 = float(latest['MA200']) if not pd.isna(latest['MA200']) else close
            macd = float(latest['MACD']) if not pd.isna(latest['MACD']) else 0
            macd_signal = float(latest['MACD_Signal']) if not pd.isna(latest['MACD_Signal']) else 0
            macd_hist = float(latest['MACD_Hist']) if not pd.isna(latest['MACD_Hist']) else 0
            adx = float(latest['ADX']) if not pd.isna(latest['ADX']) else 0
            di_plus = float(latest['DI+']) if not pd.isna(latest['DI+']) else 0
            di_minus = float(latest['DI-']) if not pd.isna(latest['DI-']) else 0
            bb_lower = float(latest['BB_Lower']) if not pd.isna(latest['BB_Lower']) else close * 0.95
            swing_low = float(latest['Swing_Low_20']) if not pd.isna(latest['Swing_Low_20']) else close * 0.9
            # ========== 6 PATTERN + MEAN REVERSION ==========
            pattern_scores = []
            if rsi < 30 and volume_ratio > 1.5 and close > swing_low:
                pattern_scores.append(20)
            if ma20 > ma50 > ma200 and close <= ma20 * 1.02 and close >= ma20 * 0.98:
                pattern_scores.append(20)
            if volume_ratio > 2.0 and close > latest['Swing_High_20']:
                pattern_scores.append(20)
            if len(df) >= 2:
                prev = df.iloc[-2]
                if df['Close'].iloc[-1] > df['Open'].iloc[-1] and df['Low'].iloc[-1] < prev['Low']:
                    pattern_scores.append(15)
            if macd > macd_signal and macd_hist > 0:
                pattern_scores.append(15)
            if adx > 20 and di_plus > di_minus:
                pattern_scores.append(10)
            is_sideways = adx < 20
            if is_sideways:
                if close <= bb_lower * 1.01 and rsi < 35 and close > swing_low:
                    pattern_scores.append(15)
            if not pattern_scores:
                return None
            raw_score = sum(pattern_scores)
            raw_score = min(raw_score, 100)
            # SL & TP
            sl = close - (atr * 1.5)
            tp = close + (atr * 2.5)
            support, resistance = get_support_resistance(df, lookback=60)
            sl = max(sl, support, close * 0.95)
            tp = min(tp, resistance)
            fraction = 5 if close < 100 else 10 if close < 500 else 25 if close < 1000 else 50
            sl = math.floor(sl / fraction) * fraction
            tp = math.ceil(tp / fraction) * fraction
            if sl >= close or tp <= close:
                return None
            min_rr = 1.3
            valid, risk, reward, rr = validate_risk_reward(close, sl, tp, min_rr)
            if not valid:
                return None
            prob_up = 0.5 + (raw_score / 200)
            prob_up = min(0.75, max(0.4, prob_up))
            ev_pct = ((prob_up * reward) - ((1 - prob_up) * risk)) / close * 100
            if ev_pct < 1.0:
                return None
            confidence = 30 + (raw_score * 0.5)
            confidence = min(95, max(20, confidence))
            lot, cost, risk_amount = self.risk_manager.calculate_lot(close, atr, symbol) if self.risk_manager else (1, close*100, atr*100)
            if lot is None:
                return None
            risk_pct = (risk_amount / self.risk_manager.modal) * 100 if self.risk_manager else 0
            composite = (ev_pct * (confidence/100)) / max(risk_pct, 0.1) * 10
            composite = min(100, composite)
            # Exit plan
            exit_plan = None
            if not is_sideways and lot >= 2:
                tp1_price = close + (atr * 1.2)
                tp1_price = min(tp1_price, resistance)
                tp1_price = math.ceil(tp1_price / fraction) * fraction
                tp2_price = close + (atr * 2.0)
                tp2_price = min(tp2_price, resistance)
                tp2_price = math.ceil(tp2_price / fraction) * fraction
                trail_activation_price = close + (atr * 1.5)
                trail_activation_price = math.ceil(trail_activation_price / fraction) * fraction
                trail_distance_mult = 2.0
                exit_plan = {
                    'type': 'SCALING_OUT',
                    'levels': [
                        {'price': tp1_price, 'sell_pct': 30},
                        {'price': tp2_price, 'sell_pct': 30}
                    ],
                    'trailing': {
                        'activation_price': trail_activation_price,
                        'distance_mult': trail_distance_mult,
                        'remaining_pct': 40
                    }
                }
            reasons_list = [f"RSI {rsi:.0f}", f"Vol {volume_ratio:.1f}x", f"Pat: {len(pattern_scores)}"]
            if is_sideways and any(p == 15 for p in pattern_scores):
                reasons_list.append("MeanRev")
            reasons = " | ".join(reasons_list)
            return {
                'Symbol': symbol,
                'Sector': get_sector(symbol),
                'Engine': 'SWING',
                'Signal_Price': int(close),
                'Stop_Loss': int(sl),
                'Take_Profit': int(tp),
                'R/R': round(rr, 2),
                'EV_Pct': round(ev_pct, 2),
                'Risk_Distance_Pct': round((close - sl)/close*100, 2),
                'Score': raw_score,
                'ATR': int(atr),
                'ATR_Pct': round(atr_pct, 1),
                'Lot': lot,
                'Cost': int(cost),
                'Risk_Amount': int(risk_amount),
                'Risk_Pct': round(risk_pct, 1),
                'Confidence_Score': round(confidence, 1),
                'Composite_Score': round(composite, 2),
                'Reasons': reasons,
                'Is_Sideways': is_sideways,
                'MeanReversion_Active': is_sideways and (close <= bb_lower * 1.01 and rsi < 35 and close > swing_low),
                'Exit_Plan': exit_plan
            }
        except Exception as e:
            logger.error(f"SwingEngine error {symbol}: {e}")
            return None


# =============================================================================
# 11. FGV ENGINE (FAIR VALUE GAP) - DIPERBAIKI DENGAN BEARISH FVG & MA FILTER
# =============================================================================
class FGVEngine:
    def __init__(self, config, global_fetcher):
        self.config = config
        self.global_fetcher = global_fetcher
        self.engine_type = 'fgv'
        self.risk_manager = None
        self.modal_adapter = ModalAdapter(config.MODAL, self.engine_type)
    def set_risk_manager(self, risk_manager: RiskManager):
        self.risk_manager = risk_manager
    def detect_bullish_fvg(self, df: pd.DataFrame) -> Optional[Dict]:
        if len(df) < 5:
            return None
        for i in range(len(df)-3, 1, -1):
            c1 = df.iloc[i-1]
            c2 = df.iloc[i]
            c3 = df.iloc[i+1]
            if c2['Close'] <= c2['Open']:
                continue
            body_pct = (c2['Close'] - c2['Open']) / c2['Open'] * 100
            if body_pct < 1.0:
                continue
            gap_high = c1['High']
            gap_low = c3['Low']
            if gap_low <= gap_high:
                continue
            gap_size_pct = (gap_low - gap_high) / gap_high * 100
            if gap_size_pct < 0.3:
                continue
            vol_ma = df['Volume'].rolling(20, min_periods=20).mean().iloc[i] if i >= 20 else 1
            if pd.isna(vol_ma):
                vol_ma = 1
            volume_ratio = c2['Volume'] / vol_ma if vol_ma > 0 else 1.0
            if volume_ratio < 1.1:
                continue
            return {
                'type': 'BULLISH',
                'fvg_low': gap_high,
                'fvg_high': gap_low,
                'candle2_close': c2['Close'],
                'volume_ratio': volume_ratio,
                'gap_size_pct': gap_size_pct,
                'idx': i
            }
        return None
    def detect_bearish_fvg(self, df: pd.DataFrame) -> Optional[Dict]:
        if len(df) < 5:
            return None
        for i in range(len(df)-3, 1, -1):
            c1 = df.iloc[i-1]
            c2 = df.iloc[i]
            c3 = df.iloc[i+1]
            if c2['Close'] >= c2['Open']:
                continue
            body_pct = (c2['Open'] - c2['Close']) / c2['Open'] * 100
            if body_pct < 1.0:
                continue
            gap_low = c1['Low']
            gap_high = c3['High']
            if gap_high >= gap_low:
                continue
            gap_size_pct = (gap_low - gap_high) / gap_low * 100
            if gap_size_pct < 0.3:
                continue
            vol_ma = df['Volume'].rolling(20, min_periods=20).mean().iloc[i] if i >= 20 else 1
            if pd.isna(vol_ma):
                vol_ma = 1
            volume_ratio = c2['Volume'] / vol_ma if vol_ma > 0 else 1.0
            if volume_ratio < 1.1:
                continue
            return {
                'type': 'BEARISH',
                'fvg_low': gap_high,
                'fvg_high': gap_low,
                'candle2_close': c2['Close'],
                'volume_ratio': volume_ratio,
                'gap_size_pct': gap_size_pct,
                'idx': i
            }
        return None
    def check_gap_mitigation(self, df: pd.DataFrame, fvg_info: Dict) -> bool:
        if len(df) < 2:
            return False
        last_candle = df.iloc[-1]
        close_price = last_candle['Close']
        if fvg_info['type'] == 'BULLISH':
            return close_price < fvg_info['fvg_low']
        else:
            return close_price > fvg_info['fvg_high']
    def get_signal(self, symbol: str, df: pd.DataFrame):
        try:
            if df is None or len(df) < 200:
                return None
            df_shifted = df.shift(1).copy()
            close = float(df_shifted['Close'].iloc[-1])
            if close <= 0:
                return None
            min_price, max_price = self.modal_adapter.get_filter_harga()
            if close < min_price or close > max_price:
                return None
            min_turn, min_avg_turn = self.modal_adapter.get_filter_turnover()
            last_turnover = close * float(df_shifted['Volume'].iloc[-1])
            avg_turnover_20 = (df_shifted['Close'] * df_shifted['Volume']).tail(20).mean()
            if last_turnover < min_turn or avg_turnover_20 < min_avg_turn:
                return None
            spread = calculate_spread_pct(df_shifted)
            if spread > self.modal_adapter.get_filter_spread():
                return None
            atr = self.risk_manager.calculate_atr_in_rupiah(df_shifted) if self.risk_manager else close * 0.02
            atr_pct = (atr / close) * 100
            if atr_pct < 1.0:
                return None
            ma200 = df_shifted['Close'].rolling(200).mean().iloc[-1]
            if pd.isna(ma200):
                ma200 = close
            bullish_fvg = self.detect_bullish_fvg(df.iloc[:-1]) if close > ma200 else None
            bearish_fvg = self.detect_bearish_fvg(df.iloc[:-1]) if close < ma200 else None
            fvg = bullish_fvg or bearish_fvg
            if not fvg:
                return None
            gap_width = fvg['fvg_high'] - fvg['fvg_low']
            tolerance = gap_width * 0.3
            entry_zone_low = fvg['fvg_low'] - tolerance
            entry_zone_high = fvg['fvg_high'] + tolerance
            if not (entry_zone_low <= close <= entry_zone_high):
                return None
            support, resistance = get_support_resistance(df_shifted, lookback=30)
            if fvg['type'] == 'BULLISH':
                sl = min(fvg['fvg_low'] - atr * 0.5, close * 0.96)
                sl = max(sl, support)
                tp = close + (atr * 1.8)
                tp = min(tp, resistance)
            else:
                sl = max(fvg['fvg_high'] + atr * 0.5, close * 1.04)
                sl = min(sl, resistance)
                tp = close - (atr * 1.8)
                tp = max(tp, support)
            fraction = 5 if close < 100 else 10 if close < 500 else 25
            sl = math.floor(sl / fraction) * fraction if fvg['type'] == 'BULLISH' else math.ceil(sl / fraction) * fraction
            tp = math.ceil(tp / fraction) * fraction if fvg['type'] == 'BULLISH' else math.floor(tp / fraction) * fraction
            if fvg['type'] == 'BULLISH':
                if sl >= close or tp <= close:
                    return None
                valid, risk, reward, rr = validate_risk_reward(close, sl, tp, min_rr=1.2)
            else:
                if sl <= close or tp >= close:
                    return None
                risk = sl - close
                reward = close - tp
                rr = reward / risk if risk > 0 else 0
                valid = rr >= 1.2
            if not valid:
                return None
            prob_up = 0.55 + (fvg['volume_ratio'] - 1.0) * 0.1 + (fvg['gap_size_pct'] / 10) * 0.05
            prob_up = min(0.75, max(0.45, prob_up))
            ev_pct = ((prob_up * reward) - ((1 - prob_up) * risk)) / close * 100
            if ev_pct < 0.8:
                return None
            confidence = 40 + (fvg['volume_ratio'] * 15) + (fvg['gap_size_pct'] * 5)
            confidence = min(90, max(30, confidence))
            lot, cost, risk_amount = self.risk_manager.calculate_lot(close, atr, symbol) if self.risk_manager else (1, close*100, atr*100)
            if lot is None:
                return None
            risk_pct = (risk_amount / self.risk_manager.modal) * 100 if self.risk_manager else 0
            composite = (ev_pct * (confidence/100)) / max(risk_pct, 0.1) * 10
            composite = min(100, composite)
            is_mitigated = self.check_gap_mitigation(df.iloc[:-1], fvg)
            return {
                'Symbol': symbol,
                'Sector': get_sector(symbol),
                'Engine': 'FGV',
                'Signal_Type': fvg['type'],
                'Signal_Price': int(close),
                'Stop_Loss': int(sl),
                'Take_Profit': int(tp),
                'R/R': round(rr, 2),
                'EV_Pct': round(ev_pct, 2),
                'Risk_Distance_Pct': round((abs(close - sl)/close)*100, 2),
                'FVG_Low': round(fvg['fvg_low'], 2),
                'FVG_High': round(fvg['fvg_high'], 2),
                'Gap_Size_Pct': round(fvg['gap_size_pct'], 1),
                'Volume_Spike': f"{fvg['volume_ratio']:.1f}x",
                'ATR': int(atr),
                'ATR_Pct': round(atr_pct, 1),
                'Lot': lot,
                'Cost': int(cost),
                'Risk_Amount': int(risk_amount),
                'Risk_Pct': round(risk_pct, 1),
                'Confidence_Score': round(confidence, 1),
                'Composite_Score': round(composite, 2),
                'Is_Mitigated': is_mitigated,
                'Reasons': f"{fvg['type']} FVG {fvg['fvg_low']:.0f}-{fvg['fvg_high']:.0f} | Gap {fvg['gap_size_pct']:.1f}% | Vol {fvg['volume_ratio']:.1f}x"
            }
        except Exception as e:
            logger.error(f"FGVEngine error {symbol}: {e}")
            return None

# =============================================================================
# 12. ADVANCED QUANT MODELS - LINEAR REGRESSION (RIDGE) DENGAN CROSS-VALIDATION
# =============================================================================
class LinearRegressionModel:
    """
    Linear Regression dengan Ridge regularization untuk mencegah overfitting.
    Menggunakan TimeSeriesSplit untuk cross-validation.
    """
    def __init__(self, lookback: int = 60, n_splits: int = 5):
        self.lookback = lookback
        self.n_splits = n_splits
        self.model = None
        self.scaler = StandardScaler()
        self.alphas = [0.1, 1.0, 10.0, 50.0, 100.0, 200.0]
        self.is_fitted = False

    def _prepare_features(self, df: pd.DataFrame) -> Tuple[np.ndarray, np.ndarray]:
        """Prepare features untuk linear regression.
        Features yang digunakan:
        1. Lag 1 return
        2. Lag 2 return
        3. Lag 3 return
        4. Lag 5 return
        5. Lag 10 return
        6. Volume change (lag 1)
        7. RSI (jika tersedia)
        8. Volatility (ATR/Close)
        """
        close = df['Close'].values
        volume = df['Volume'].values

        # Returns
        returns = np.diff(close) / close[:-1]
        returns = np.insert(returns, 0, 0)

        # Lag features
        X = np.column_stack([
            np.roll(returns, 1),   # lag1
            np.roll(returns, 2),   # lag2
            np.roll(returns, 3),   # lag3
            np.roll(returns, 5),   # lag5
            np.roll(returns, 10),  # lag10
        ])

        # Volume change
        vol_change = np.diff(volume) / (volume[:-1] + 1e-6)
        vol_change = np.insert(vol_change, 0, 0)
        X = np.column_stack([X, np.roll(vol_change, 1)])

        # RSI if available
        if 'RSI' in df.columns:
            rsi = df['RSI'].values
            X = np.column_stack([X, np.roll(rsi, 1)])

        # Volatility (ATR/Close) - approximated using rolling std
        vol_window = min(20, len(close)//2)
        rolling_std = pd.Series(returns).rolling(vol_window).std().fillna(0).values
        X = np.column_stack([X, rolling_std])

        # Target: next day return
        y = np.roll(returns, -1)

        # Remove rows with NaN
        mask = ~(np.isnan(X).any(axis=1) | np.isnan(y))
        X = X[mask]
        y = y[mask]

        return X, y

    def fit(self, df: pd.DataFrame) -> None:
        """Fit model dengan RidgeCV yang melakukan cross-validation internal."""
        X, y = self._prepare_features(df)

        if len(X) < self.lookback * 2:
            self.is_fitted = False
            return

        # Scale features
        X_scaled = self.scaler.fit_transform(X)

        # RidgeCV dengan cross-validation untuk memilih alpha terbaik
        # Ini adalah bentuk internal cross-validation untuk mencegah overfitting
        ridge_cv = RidgeCV(alphas=self.alphas, scoring='neg_mean_squared_error', cv=min(self.n_splits, len(X)//10))
        ridge_cv.fit(X_scaled, y)

        self.model = ridge_cv
        self.is_fitted = True

    def predict_direction(self, df: pd.DataFrame) -> float:
        """Predict next day direction (1 untuk up, -1 untuk down, 0 untuk neutral)."""
        if not self.is_fitted:
            return 0

        X, _ = self._prepare_features(df)
        if len(X) == 0:
            return 0

        X_scaled = self.scaler.transform(X[-1:])
        pred = self.model.predict(X_scaled)[0]

        if pred > 0.002:  # threshold 0.2% untuk sinyal beli
            return 1
        elif pred < -0.002:
            return -1
        else:
            return 0

# =============================================================================
# 13. ADVANCED QUANT MODELS - KALMAN FILTER (SIMDKALMAN)
# =============================================================================
class KalmanFilterModel:
    """
    Kalman Filter untuk signal extraction menggunakan pykalman.
    pykalman lebih stabil dan tidak memiliki masalah API seperti simdkalman.
    """
    def __init__(self, observation_noise: float = 0.01, process_noise: float = 0.001):
        self.observation_noise = observation_noise
        self.process_noise = process_noise
        self.kf = None

    def _create_filter(self):
        """Create Kalman filter using pykalman."""
        from pykalman import KalmanFilter
        # State: [price, velocity]
        # Transition matrix: price_t+1 = price_t + velocity_t
        #                    velocity_t+1 = velocity_t
        transition_matrices = np.array([[1, 1],
                                        [0, 1]])

        # Observation matrix: kita observe price saja
        observation_matrices = np.array([[1, 0]])

        # Initial state
        initial_state_mean = np.array([0, 0])
        initial_state_covariance = np.eye(2) * 1.0

        # Noise covariances
        transition_covariance = np.array([[self.process_noise, 0],
                                          [0, self.process_noise * 0.1]])
        observation_covariance = np.array([[self.observation_noise]])

        self.kf = KalmanFilter(
            transition_matrices=transition_matrices,
            observation_matrices=observation_matrices,
            initial_state_mean=initial_state_mean,
            initial_state_covariance=initial_state_covariance,
            transition_covariance=transition_covariance,
            observation_covariance=observation_covariance
        )

    def filter_prices(self, prices: np.ndarray) -> np.ndarray:
        """Filter price series using Kalman filter."""
        if self.kf is None:
            self._create_filter()

        # Run filter (smooth=True untuk hasil yang lebih halus)
        state_means, _ = self.kf.filter(prices.reshape(-1, 1))
        filtered_prices = state_means[:, 0]
        return filtered_prices

    def get_trend_direction(self, df: pd.DataFrame) -> int:
        """Get trend direction (1: up, -1: down, 0: sideways)."""
        try:
            prices = df['Close'].values[-100:]
            if len(prices) < 30:
                return 0

            filtered = self.filter_prices(prices)

            # Calculate slope of filtered series over last 10 days
            if len(filtered) >= 10:
                slope = (filtered[-1] - filtered[-10]) / (filtered[-10] + 1e-6)
            else:
                slope = 0

            if slope > 0.005:   # 0.5% slope threshold
                return 1
            elif slope < -0.005:
                return -1
            else:
                return 0
        except Exception as e:
            logger.warning(f"Kalman filter error: {e}")
            return 0

# =============================================================================
# 14. ADVANCED QUANT MODELS - GARCH (VOLATILITY MODELING)
# =============================================================================
class GARCHModel:
    """
    GARCH(1,1) untuk volatility forecasting dengan rolling window.
    Rolling window mencegah overfitting dengan selalu menggunakan data terbaru.
    """
    def __init__(self, window: int = 500, forecast_horizon: int = 5):
        self.window = window
        self.forecast_horizon = forecast_horizon
        self._check_stationary = True

    def _is_stationary(self, returns: np.ndarray) -> bool:
        """Check if return series is stationary using ADF test."""
        from statsmodels.tsa.stattools import adfuller
        try:
            result = adfuller(returns)
            return result[1] < 0.05
        except:
            return True

    def forecast_volatility(self, df: pd.DataFrame) -> float:
        """Forecast volatility using GARCH(1,1) with rolling window."""
        # Calculate returns
        returns = df['Close'].pct_change().dropna().values * 100

        if len(returns) < self.window:
            # Not enough data, use rolling standard deviation
            return np.std(returns[-min(60, len(returns)):]) if len(returns) > 0 else 0.02

        # Use rolling window (most recent data only)
        recent_returns = returns[-self.window:]

        # Check stationarity
        if self._check_stationary and not self._is_stationary(recent_returns):
            # If not stationary, use simpler volatility estimate
            return np.std(recent_returns)

        try:
            # Fit GARCH(1,1) model
            model = arch_model(recent_returns, vol='Garch', p=1, q=1, dist='normal')
            model_fit = model.fit(disp='off', show_warning=False)

            # Forecast volatility
            forecast = model_fit.forecast(horizon=self.forecast_horizon)
            vol_forecast = np.sqrt(forecast.variance.values[-1, :]).mean()

            # Sanity check - prevent extreme values
            vol_forecast = np.clip(vol_forecast, 0.005, 0.1)

            return vol_forecast / 100  # convert back from percentage

        except Exception:
            # Fallback to rolling std
            return np.std(recent_returns) / 100

    def get_volatility_multiplier(self, df: pd.DataFrame, base_multiplier: float = 1.0) -> float:
        """Get risk multiplier based on GARCH forecasted volatility."""
        forecast_vol = self.forecast_volatility(df)

        # Historical volatility as baseline
        returns = df['Close'].pct_change().dropna().values
        hist_vol = np.std(returns[-min(60, len(returns)):]) if len(returns) > 0 else 0.02

        if hist_vol == 0:
            return base_multiplier

        vol_ratio = forecast_vol / hist_vol

        # Adjust multiplier: higher volatility -> lower risk
        if vol_ratio > 1.5:
            return base_multiplier * 0.5
        elif vol_ratio > 1.2:
            return base_multiplier * 0.7
        elif vol_ratio < 0.8:
            return base_multiplier * 1.2
        else:
            return base_multiplier

# =============================================================================
# 15. ADVANCED QUANT MODELS - HMM (REGIME DETECTION)
# =============================================================================
class HMMRegimeModel:
    """
    Hidden Markov Model for market regime detection.
    Uses BIC for automatic state selection to prevent overfitting.
    """
    def __init__(self, n_states_range: List[int] = [2, 3, 4], n_iter: int = 100):
        self.n_states_range = n_states_range
        self.n_iter = n_iter
        self.model = None
        self.best_n_states = None
        self.regime_mapping = {}

    def _select_optimal_states(self, X: np.ndarray) -> int:
        """Select optimal number of states using Bayesian Information Criterion."""
        best_bic = np.inf
        best_n = self.n_states_range[0]

        for n in self.n_states_range:
            try:
                model = hmm.GaussianHMM(n_components=n, covariance_type="full", n_iter=self.n_iter, random_state=42)
                model.fit(X)
                bic = model.bic(X)
                if bic < best_bic:
                    best_bic = bic
                    best_n = n
            except:
                continue

        return best_n

    def fit(self, df: pd.DataFrame) -> None:
        """Fit HMM on historical returns."""
        returns = df['Close'].pct_change().dropna().values.reshape(-1, 1)

        if len(returns) < 200:
            self.model = None
            return

        # Use returns and volatility as features
        volatility = pd.Series(returns.flatten()).rolling(20).std().fillna(0).values.reshape(-1, 1)
        X = np.hstack([returns, volatility])
        X = X[~np.isnan(X).any(axis=1)]

        if len(X) < 100:
            self.model = None
            return

        # Select optimal number of states
        self.best_n_states = self._select_optimal_states(X)

        # Fit final model
        try:
            self.model = hmm.GaussianHMM(n_components=self.best_n_states, covariance_type="full",
                                         n_iter=self.n_iter, random_state=42, tol=0.01)
            self.model.fit(X)
        except:
            self.model = None

    def predict_regime(self, df: pd.DataFrame) -> Dict:
        """Predict current market regime."""
        if self.model is None:
            return {'regime': 'NEUTRAL', 'volatility_regime': 'NORMAL', 'confidence': 0.5}

        returns = df['Close'].pct_change().dropna().values[-50:].reshape(-1, 1)
        volatility = pd.Series(returns.flatten()).rolling(20).std().fillna(0).values[-50:].reshape(-1, 1)
        X = np.hstack([returns, volatility])
        X = X[~np.isnan(X).any(axis=1)]

        if len(X) == 0:
            return {'regime': 'NEUTRAL', 'volatility_regime': 'NORMAL', 'confidence': 0.5}

        try:
            states = self.model.predict(X)
            current_state = states[-1]

            # Analyze state characteristics
            state_means = self.model.means_
            state_covars = self.model.covars_

            # Map state to regime based on mean return and volatility
            mean_return = state_means[current_state][0]
            volatility_level = np.sqrt(state_covars[current_state][0][0])

            if mean_return > 0.002 and volatility_level < 0.02:
                regime = 'BULL'
            elif mean_return > 0.002 and volatility_level >= 0.02:
                regime = 'BULL_HIGH_VOL'
            elif mean_return < -0.002 and volatility_level < 0.02:
                regime = 'BEAR'
            elif mean_return < -0.002 and volatility_level >= 0.02:
                regime = 'BEAR_HIGH_VOL'
            else:
                regime = 'SIDEWAYS'

            # Classify volatility regime
            if volatility_level < 0.015:
                vol_regime = 'LOW'
            elif volatility_level < 0.03:
                vol_regime = 'NORMAL'
            else:
                vol_regime = 'HIGH'

            # Calculate confidence based on state probability
            posteriors = self.model.predict_proba(X)
            confidence = float(posteriors[-1][current_state])

            return {
                'regime': regime,
                'volatility_regime': vol_regime,
                'confidence': confidence,
                'mean_return': mean_return,
                'volatility': volatility_level
            }
        except:
            return {'regime': 'NEUTRAL', 'volatility_regime': 'NORMAL', 'confidence': 0.5}

    def get_regime_multiplier(self, df: pd.DataFrame) -> float:
        """Get position sizing multiplier based on detected regime."""
        regime_info = self.predict_regime(df)

        multipliers = {
            'BULL': 1.2,
            'BULL_HIGH_VOL': 0.8,
            'BEAR': 0.5,
            'BEAR_HIGH_VOL': 0.3,
            'SIDEWAYS': 0.7,
            'NEUTRAL': 0.7
        }

        base_multiplier = multipliers.get(regime_info['regime'], 0.7)

        # Adjust by confidence
        confidence = regime_info['confidence']
        if confidence < 0.6:
            base_multiplier *= 0.8

        return base_multiplier

# =============================================================================
# 16. ADVANCED QUANT MODELS - ARIMA (TIME SERIES FORECASTING)
# =============================================================================
class ARIMAModel:
    """
    ARIMA for price forecasting with auto_arima parameter selection.
    Auto_arima uses AIC to select optimal parameters, preventing overfitting.
    """
    def __init__(self, max_p: int = 5, max_d: int = 2, max_q: int = 5):
        self.max_p = max_p
        self.max_d = max_d
        self.max_q = max_q
        self.model = None
        self.is_fitted = False

    def fit(self, df: pd.DataFrame) -> None:
        """Fit ARIMA model with automatic parameter selection."""
        series = df['Close'].values

        if len(series) < 100:
            self.is_fitted = False
            return

        try:
            # Auto_arima uses AIC to select best parameters
            self.model = auto_arima(series, start_p=1, max_p=self.max_p, start_d=0, max_d=self.max_d,
                                   start_q=1, max_q=self.max_q, seasonal=False, stepwise=True,
                                   suppress_warnings=True, error_action='ignore', n_fits=50,
                                   information_criterion='aic')
            self.is_fitted = True
        except:
            self.is_fitted = False

    def forecast_direction(self, df: pd.DataFrame, horizon: int = 5) -> int:
        """Forecast direction (1: up, -1: down, 0: neutral) over specified horizon."""
        if not self.is_fitted:
            return 0

        try:
            forecast, conf_int = self.model.predict(n_periods=horizon, return_conf_int=True)

            # Get current price
            current_price = df['Close'].iloc[-1]
            forecast_price = forecast[-1]

            # Calculate expected return
            expected_return = (forecast_price - current_price) / current_price

            # Confidence check using confidence intervals
            upper_bound = conf_int[-1][1] if conf_int is not None else forecast_price * 1.02
            lower_bound = conf_int[-1][0] if conf_int is not None else forecast_price * 0.98

            # Only signal if forecast is strong and confidence interval is tight
            if expected_return > 0.02 and (upper_bound - lower_bound) / current_price < 0.05:
                return 1
            elif expected_return < -0.02 and (upper_bound - lower_bound) / current_price < 0.05:
                return -1
            else:
                return 0
        except:
            return 0

# =============================================================================
# 17. ADVANCED QUANT MODELS - MONTE CARLO (SCENARIO SIMULATION)
# =============================================================================
class MonteCarloSimulation:
    """
    Monte Carlo simulation for risk assessment using bootstrap historical returns.
    Bootstrap method avoids parametric assumptions about return distribution.
    """
    def __init__(self, n_simulations: int = 1000, n_days: int = 20):
        self.n_simulations = n_simulations
        self.n_days = n_days

    def simulate_paths(self, df: pd.DataFrame) -> np.ndarray:
        """Generate Monte Carlo price paths using bootstrap resampling."""
        # Calculate historical returns
        returns = df['Close'].pct_change().dropna().values
        current_price = df['Close'].iloc[-1]

        if len(returns) < 50:
            # Not enough data, use normal distribution approximation
            mu = np.mean(returns)
            sigma = np.std(returns)
            returns_bootstrap = np.random.normal(mu, sigma, (self.n_simulations, self.n_days))
        else:
            # Bootstrap: randomly sample from historical returns with replacement
            idx = np.random.randint(0, len(returns), (self.n_simulations, self.n_days))
            returns_bootstrap = returns[idx]

        # Calculate price paths
        cumulative_returns = np.cumprod(1 + returns_bootstrap, axis=1)
        price_paths = current_price * cumulative_returns

        return price_paths

    def calculate_probability(self, df: pd.DataFrame, target_price: float, is_upper: bool = True) -> float:
        """Calculate probability that price reaches target within simulation horizon."""
        price_paths = self.simulate_paths(df)

        if is_upper:
            # Probability of reaching or exceeding target
            reached = np.any(price_paths >= target_price, axis=1)
        else:
            # Probability of reaching or falling below target
            reached = np.any(price_paths <= target_price, axis=1)

        return np.mean(reached)

    def get_expected_return(self, df: pd.DataFrame) -> float:
        """Get expected return from Monte Carlo simulation."""
        price_paths = self.simulate_paths(df)
        final_prices = price_paths[:, -1]
        current_price = df['Close'].iloc[-1]

        expected_price = np.mean(final_prices)
        expected_return = (expected_price - current_price) / current_price

        # Also calculate confidence interval
        lower_percentile = np.percentile(final_prices, 5)
        upper_percentile = np.percentile(final_prices, 95)

        return {
            'expected_return': expected_return,
            'lower_bound': (lower_percentile - current_price) / current_price,
            'upper_bound': (upper_percentile - current_price) / current_price,
            'prob_positive': np.mean(final_prices > current_price)
        }

    def get_risk_metrics(self, df: pd.DataFrame, entry_price: float, stop_loss: float, take_profit: float) -> Dict:
        """Get risk metrics for a specific trade setup."""
        price_paths = self.simulate_paths(df)
        current_price = df['Close'].iloc[-1]

        n_sim = self.n_simulations
        hit_sl = 0
        hit_tp = 0

        for path in price_paths:
            for price in path:
                if price <= stop_loss:
                    hit_sl += 1
                    break
                if price >= take_profit:
                    hit_tp += 1
                    break

        prob_sl = hit_sl / n_sim
        prob_tp = hit_tp / n_sim
        prob_neutral = 1 - prob_sl - prob_tp

        # Expected PnL
        risk_amount = (entry_price - stop_loss) / entry_price
        reward_amount = (take_profit - entry_price) / entry_price

        expected_return_pct = (prob_tp * reward_amount) - (prob_sl * risk_amount)

        return {
            'prob_hit_stop_loss': prob_sl,
            'prob_hit_take_profit': prob_tp,
            'prob_neutral': prob_neutral,
            'expected_return_pct': expected_return_pct * 100,
            'risk_reward_ratio': reward_amount / risk_amount if risk_amount > 0 else 0
        }

# =============================================================================
# 18. ADVANCED QUANT MODELS - NEURAL NETWORK LSTM
# =============================================================================
class LSTMNeuralNetwork:
    """
    LSTM Neural Network with dropout and early stopping to prevent overfitting.
    Architecture is intentionally small to avoid memorizing noise.
    """
    def __init__(self, sequence_length: int = 20, n_features: int = 5,
                 lstm_units: int = 32, dropout_rate: float = 0.3):
        self.sequence_length = sequence_length
        self.n_features = n_features
        self.lstm_units = lstm_units
        self.dropout_rate = dropout_rate
        self.model = None
        self.scaler = StandardScaler()
        self.is_trained = False

    def _build_model(self) -> Sequential:
        """Build LSTM model with regularization layers."""
        model = Sequential([
            LSTM(self.lstm_units, return_sequences=True, input_shape=(self.sequence_length, self.n_features),
                 kernel_regularizer=l2(0.001), recurrent_regularizer=l2(0.001)),
            BatchNormalization(),
            Dropout(self.dropout_rate),
            LSTM(self.lstm_units // 2, return_sequences=False,
                 kernel_regularizer=l2(0.001), recurrent_regularizer=l2(0.001)),
            BatchNormalization(),
            Dropout(self.dropout_rate * 0.8),
            Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
            Dropout(self.dropout_rate * 0.5),
            Dense(1, activation='linear')
        ])

        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                     loss='mse', metrics=['mae'])
        return model

    def _prepare_sequences(self, df: pd.DataFrame) -> Tuple[np.ndarray, np.ndarray]:
        """Prepare sequences for LSTM training."""
        # Features: returns, volume change, RSI, volatility, price position
        close = df['Close'].values
        volume = df['Volume'].values

        returns = np.diff(close) / (close[:-1] + 1e-6)
        returns = np.insert(returns, 0, 0)

        vol_change = np.diff(volume) / (volume[:-1] + 1e-6)
        vol_change = np.insert(vol_change, 0, 0)

        # RSI
        if 'RSI' in df.columns:
            rsi = df['RSI'].values
        else:
            delta = np.diff(close)
            gain = np.where(delta > 0, delta, 0)
            loss = np.where(delta < 0, -delta, 0)
            avg_gain = pd.Series(gain).rolling(14).mean().fillna(0).values
            avg_loss = pd.Series(loss).rolling(14).mean().fillna(0).values
            rs = avg_gain / (avg_loss + 1e-6)
            rsi = 100 - (100 / (1 + rs))

        # Volatility (rolling std of returns)
        vol = pd.Series(returns).rolling(20).std().fillna(0).values

        # Price position within range
        rolling_min = pd.Series(close).rolling(50).min().fillna(close).values
        rolling_max = pd.Series(close).rolling(50).max().fillna(close).values
        price_position = (close - rolling_min) / (rolling_max - rolling_min + 1e-6)

        # Stack features
        features = np.column_stack([returns, vol_change, rsi, vol, price_position])

        # Target: next day return
        target = np.roll(returns, -1)

        # Create sequences
        X, y = [], []
        for i in range(len(features) - self.sequence_length - 1):
            X.append(features[i:i+self.sequence_length])
            y.append(target[i+self.sequence_length])

        X = np.array(X)
        y = np.array(y)

        return X, y

    def train(self, df: pd.DataFrame, epochs: int = 50, validation_split: float = 0.2) -> None:
        """Train LSTM model with early stopping."""
        X, y = self._prepare_sequences(df)

        if len(X) < 100:
            self.is_trained = False
            return

        # Scale features
        n_samples, seq_len, n_feat = X.shape
        X_reshaped = X.reshape(-1, n_feat)
        X_scaled = self.scaler.fit_transform(X_reshaped)
        X = X_scaled.reshape(n_samples, seq_len, n_feat)

        # Build model
        self.model = self._build_model()

        # Early stopping to prevent overfitting
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

        # Train with validation split
        try:
            self.model.fit(X, y, epochs=epochs, batch_size=32,
                          validation_split=validation_split,
                          callbacks=[early_stop, reduce_lr],
                          verbose=0)
            self.is_trained = True
        except:
            self.is_trained = False

    def predict_confidence(self, df: pd.DataFrame) -> float:
        """Predict confidence score for current setup."""
        if not self.is_trained or self.model is None:
            return 0.5

        X, _ = self._prepare_sequences(df)
        if len(X) == 0:
            return 0.5

        # Get most recent sequence
        X_last = X[-1:]
        n_samples, seq_len, n_feat = X_last.shape
        X_last_reshaped = X_last.reshape(-1, n_feat)
        X_last_scaled = self.scaler.transform(X_last_reshaped)
        X_last = X_last_scaled.reshape(n_samples, seq_len, n_feat)

        # Predict
        prediction = self.model.predict(X_last, verbose=0)[0][0]

        # Convert prediction to confidence score (sigmoid-like)
        confidence = 1 / (1 + np.exp(-prediction * 10))

        return float(confidence)

# =============================================================================
# 19. ADVANCED SIGNAL PROCESSOR (INTEGRATES ALL 7 MODELS)
# =============================================================================
class AdvancedSignalProcessor:
    """
    Integrates all 7 advanced quant models to generate final confidence score.
    Uses ensemble approach to reduce overfitting.
    """
    def __init__(self):
        self.linear_regression = LinearRegressionModel()
        self.kalman_filter = KalmanFilterModel()
        self.garch_model = GARCHModel()
        self.hmm_model = HMMRegimeModel()
        self.arima_model = ARIMAModel()
        self.monte_carlo = MonteCarloSimulation()
        self.lstm_model = LSTMNeuralNetwork()

        # Model weights (can be adjusted based on market conditions)
        self.weights = {
            'linear_regression': 0.15,
            'kalman_filter': 0.15,
            'garch': 0.10,
            'hmm': 0.15,
            'arima': 0.15,
            'monte_carlo': 0.10,
            'lstm': 0.20
        }

        self._is_fitted = False

    def fit_models(self, df: pd.DataFrame) -> None:
        """Fit all models on historical data."""
        try:
            self.linear_regression.fit(df)
            self.arima_model.fit(df)
            self.hmm_model.fit(df)
            # LSTM training is heavy, only train if data is sufficient
            if len(df) > 500:
                try:
                    self.lstm_model.train(df)
                except:
                    pass
            self._is_fitted = True
        except Exception as e:
            logger.error(f"Error fitting advanced models: {e}")
            self._is_fitted = False

    def process_signal(self, df: pd.DataFrame, base_signal: Dict) -> Dict:
        """
        Process base signal through all advanced models to generate enhanced signal.
        """
        if not self._is_fitted or df is None or len(df) < 200:
            return base_signal

        try:
            # Get predictions from each model
            lr_direction = self.linear_regression.predict_direction(df)
            kf_trend = self.kalman_filter.get_trend_direction(df)
            vol_mult = self.garch_model.get_volatility_multiplier(df)
            regime_info = self.hmm_model.predict_regime(df)
            regime_mult = self.hmm_model.get_regime_multiplier(df)
            arima_dir = self.arima_model.forecast_direction(df)

            # Monte Carlo for risk assessment
            entry = base_signal['Signal_Price']
            sl = base_signal['Stop_Loss']
            tp = base_signal['Take_Profit']
            mc_risk = self.monte_carlo.get_risk_metrics(df, entry, sl, tp)

            # LSTM confidence
            lstm_conf = self.lstm_model.predict_confidence(df) if self.lstm_model.is_trained else 0.5

            # Combine predictions
            direction_score = 0
            n_directions = 0

            if lr_direction != 0:
                direction_score += lr_direction
                n_directions += 1
            if kf_trend != 0:
                direction_score += kf_trend
                n_directions += 1
            if arima_dir != 0:
                direction_score += arima_dir
                n_directions += 1

            avg_direction = direction_score / n_directions if n_directions > 0 else 0

            # Regime-based adjustment
            regime_adjustment = 1.0
            if regime_info['regime'] == 'BULL':
                regime_adjustment = 1.2
            elif regime_info['regime'] == 'BEAR':
                regime_adjustment = 0.4
            elif regime_info['regime'] == 'SIDEWAYS':
                regime_adjustment = 0.7

            # Monte Carlo based confidence
            mc_confidence = mc_risk['prob_hit_take_profit'] * 100
            mc_confidence = min(100, max(0, mc_confidence))

            # Combined confidence score
            weighted_confidence = (
                self.weights['linear_regression'] * (50 + lr_direction * 25) +
                self.weights['kalman_filter'] * (50 + kf_trend * 25) +
                self.weights['garch'] * (50 + (1 - vol_mult) * 50) +
                self.weights['hmm'] * (50 + (regime_mult - 0.7) * 100) +
                self.weights['arima'] * (50 + arima_dir * 25) +
                self.weights['monte_carlo'] * mc_confidence +
                self.weights['lstm'] * lstm_conf * 100
            )

            # Final adjustments
            if avg_direction < 0:
                weighted_confidence *= 0.5

            weighted_confidence *= regime_adjustment
            weighted_confidence = min(95, max(10, weighted_confidence))

            # Update base signal with advanced metrics
            enhanced_signal = base_signal.copy()
            enhanced_signal['Advanced_Confidence'] = round(weighted_confidence, 1)
            enhanced_signal['Advanced_Composite'] = round(weighted_confidence * (base_signal.get('EV_Pct', 5) / 10), 2)
            enhanced_signal['Regime'] = regime_info['regime']
            enhanced_signal['Volatility_Regime'] = regime_info['volatility_regime']
            enhanced_signal['MC_Prob_TP'] = round(mc_risk['prob_hit_take_profit'] * 100, 1)
            enhanced_signal['MC_Prob_SL'] = round(mc_risk['prob_hit_stop_loss'] * 100, 1)
            enhanced_signal['Advanced_Reasons'] = (
                f"LR:{lr_direction} KF:{kf_trend} ARIMA:{arima_dir} "
                f"Regime:{regime_info['regime']} VolAdj:{vol_mult:.1f}"
            )

            # Only keep signal if advanced confidence is good enough
            if weighted_confidence < 25:
                return None

            return enhanced_signal

        except Exception as e:
            logger.error(f"Error processing advanced signal: {e}")
            return base_signal

# =============================================================================
# 20. PORTFOLIO BUILDER (EQUAL RISK CONTRIBUTION + CORRELATION FILTER)
# =============================================================================
class PortfolioBuilder:
    def __init__(self, modal: float, max_positions: int = 10, max_correlation: float = 0.7, max_per_sector: int = 2):
        self.modal = modal
        self.max_positions = max_positions
        self.max_correlation = max_correlation
        self.max_per_sector = max_per_sector

    def build(self, signals: List[Dict], price_data: Dict[str, pd.DataFrame], risk_manager: RiskManager) -> List[Dict]:
        if not signals:
            return []
        # Sort by composite score (use Advanced_Composite if available)
        signals_sorted = sorted(signals, key=lambda x: x.get('Advanced_Composite', x.get('Composite_Score', 0)), reverse=True)
        selected = []
        sector_count = defaultdict(int)
        # Correlation check
        for sig in signals_sorted:
            if len(selected) >= self.max_positions:
                break
            sym = sig['Symbol']
            sector = sig.get('Sector', 'OTHER')
            if sector_count[sector] >= self.max_per_sector:
                continue
            # Check correlation with already selected symbols
            correlated = False
            for sel in selected:
                sel_sym = sel['Symbol']
                if sel_sym in price_data and sym in price_data:
                    df1 = price_data[sel_sym]['Close'].pct_change().dropna().tail(60)
                    df2 = price_data[sym]['Close'].pct_change().dropna().tail(60)
                    if len(df1) > 20 and len(df2) > 20:
                        corr = df1.corr(df2)
                        if abs(corr) > self.max_correlation:
                            correlated = True
                            break
            if correlated:
                continue
            # Check risk budget
            can_add, _ = risk_manager.can_add_position(sig['Risk_Amount'], sig['Cost'])
            if can_add:
                selected.append(sig)
                sector_count[sector] += 1
                risk_manager.add_position(sym, sig['Lot'], sig['Signal_Price'], sig['Risk_Amount'], sig['Cost'])
        return selected

# =============================================================================
# 21. GOOGLE SHEETS EXPORTER (PERTAHANKAN)
# =============================================================================
class GoogleSheetsExporter:
    def __init__(self):
        self.initialized = False
        self.spreadsheet = None
        self._url_printed = False
        self.HEADERS = ['Date', 'Engine', 'Symbol', 'Signal_Price', 'SL', 'TP', 'R/R', 'RiskDist%', 'EV%', 'Conf%', 'Composite', 'Notes']

    def _init_sheets(self):
        try:
            auth.authenticate_user()
            creds, _ = default()
            self.gc = gspread.authorize(creds)
            self.initialized = True
            print("✅ Berhasil konek ke Google Sheets")
            return True
        except Exception as e:
            print(f"❌ Gagal konek ke Google Sheets: {e}")
            return False

    def _get_or_create_spreadsheet(self, sheet_name):
        try:
            self.spreadsheet = self.gc.open(sheet_name)
        except:
            self.spreadsheet = self.gc.create(sheet_name)
            print(f"✅ Membuat spreadsheet baru: {sheet_name}")
        return self.spreadsheet

    def _get_or_create_engine_sheet(self, engine_name):
        sheet_title = engine_name.replace(' ', '_')[:100]
        try:
            worksheet = self.spreadsheet.worksheet(sheet_title)
            existing = worksheet.row_values(1)
            if existing != self.HEADERS:
                worksheet.clear()
                worksheet.append_row(self.HEADERS)
        except:
            worksheet = self.spreadsheet.add_worksheet(title=sheet_title, rows=10000, cols=len(self.HEADERS))
            worksheet.append_row(self.HEADERS)
        return worksheet

    def ensure_spreadsheet_exists(self):
        if not self.initialized:
            if not self._init_sheets():
                return False
        if not self.spreadsheet:
            self._get_or_create_spreadsheet("IDX_Scanner_Medallion")
        if not self._url_printed:
            print(f"\n📊 Google Sheets URL: {self.spreadsheet.url}")
            self._url_printed = True
        return True

    def export_signals(self, signals, engine_name, modal, summary_data=None):
        if not signals:
            print(f"ℹ️ Tidak ada sinyal untuk {engine_name}")
            return False
        if not self.initialized:
            if not self._init_sheets():
                return False
        try:
            if not self.spreadsheet:
                self._get_or_create_spreadsheet("IDX_Scanner_Medallion")
            worksheet = self._get_or_create_engine_sheet(engine_name)
            for s in signals:
                row = [
                    datetime.now().strftime('%Y-%m-%d'),
                    s.get('Engine', engine_name),
                    s['Symbol'],
                    s['Signal_Price'],
                    s.get('Stop_Loss', '-'),
                    s.get('Take_Profit', '-'),
                    s.get('R/R', '-'),
                    s.get('Risk_Distance_Pct', '-'),
                    s.get('EV_Pct', '-'),
                    s.get('Advanced_Confidence', s.get('Confidence_Score', '-')),
                    s.get('Advanced_Composite', s.get('Composite_Score', '-')),
                    s.get('Advanced_Reasons', s.get('Reasons', ''))
                ]
                worksheet.append_row(row)
            print(f"✅ Export {len(signals)} sinyal ke {engine_name}")
            return True
        except Exception as e:
            print(f"❌ Gagal export: {e}")
            return False

# =============================================================================
# 22. CHART GENERATOR (PERTAHANKAN)
# =============================================================================
def generate_signal_chart(signal: Dict, df: pd.DataFrame, engine_type: str, save_dir: str = 'charts') -> Optional[str]:
    os.makedirs(save_dir, exist_ok=True)
    symbol = signal['Symbol']
    signal_date = df.index[-1]
    signal_price = signal['Signal_Price']
    n = 90
    plot_df = df.tail(n).copy()
    plot_df = plot_df.dropna(subset=['Open', 'High', 'Low', 'Close', 'Volume'])
    if len(plot_df) < 5:
        return None
    plot_df = plot_df.sort_index()
    if not isinstance(plot_df.index, pd.DatetimeIndex):
        plot_df.index = pd.to_datetime(plot_df.index)
    plot_df['MA20'] = plot_df['Close'].rolling(20).mean()
    plot_df['MA50'] = plot_df['Close'].rolling(50).mean()
    # RSI
    delta = plot_df['Close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(14).mean()
    avg_loss = loss.rolling(14).mean()
    rs = avg_gain / (avg_loss + 1e-6)
    plot_df['RSI'] = 100 - (100 / (1 + rs))
    apds = []
    # Volume subplot
    apds.append(mpf.make_addplot(plot_df['Volume'], panel=1, type='bar', color='gray', alpha=0.5, ylabel='Volume'))
    # RSI subplot
    if plot_df['RSI'].notna().any():
        apds.append(mpf.make_addplot(plot_df['RSI'], panel=2, color='purple', ylabel='RSI', ylim=(0,100)))
    # MAs
    if plot_df['MA20'].notna().any():
        apds.append(mpf.make_addplot(plot_df['MA20'], color='orange', width=1))
    if plot_df['MA50'].notna().any():
        apds.append(mpf.make_addplot(plot_df['MA50'], color='green', width=1))
    try:
        fig, axes = mpf.plot(plot_df, type='candle', volume=False, addplot=apds,
                             title=f"{symbol} - {engine_type.upper()} SIGNAL ({signal_date.strftime('%Y-%m-%d')})",
                             ylabel='Price', figsize=(14, 10), style='charles', returnfig=True)
    except Exception as e:
        return None
    ax = axes[0]
    ax.axhline(y=signal_price, color='blue', linestyle='--', linewidth=1, alpha=0.7, label='Entry')
    sl = signal.get('Stop_Loss')
    if sl:
        ax.axhline(y=sl, color='red', linestyle='--', linewidth=1, alpha=0.7, label='Stop Loss')
    tp = signal.get('Take_Profit')
    if tp:
        ax.axhline(y=tp, color='green', linestyle='--', linewidth=1, alpha=0.7, label='Target')
    ax.legend(loc='upper left')
    filename = f"{save_dir}/{engine_type}_{symbol}_{signal_date.strftime('%Y%m%d')}.png"
    plt.savefig(filename, dpi=100, bbox_inches='tight')
    plt.close(fig)
    return filename

# =============================================================================
# RUN_SYSTEM_BACKTEST DENGAN PARALELISASI PER PERIODE + VECTORBT
# =============================================================================
def run_system_backtest(force_refresh=False, interval_days=20, forward_hold_days=10, modal=5_000_000):
    """
    Backtest walk-forward dengan partial take profit dan trailing stop.
    Menggunakan paralelisasi per periode dan VectorBT untuk simulasi portofolio.
    """
    print("\n" + "="*80)
    print("📊 SYSTEM QUALITY DASHBOARD (End-to-End Backtest) - PARALLEL PER PERIODE + VECTORBT")
    print("="*80)

    warehouse = DataWarehouse(warehouse_dir='data_warehouse', min_days=400)
    symbols = warehouse.get_all_valid_symbols()
    if not symbols:
        print("❌ Data warehouse kosong.")
        return

    end_date = pd.Timestamp.now().normalize()
    start_date = end_date - pd.Timedelta(days=20*365)
    print(f"Periode: {start_date.date()} - {end_date.date()} | Saham: {len(symbols)}")
    print(f"Interval scanning: setiap {interval_days} hari | Holding: {forward_hold_days} hari | Modal simulasi: Rp {modal:,}")

    cache_params = {
        'start': start_date.strftime('%Y-%m-%d'),
        'end': end_date.strftime('%Y-%m-%d'),
        'interval_days': interval_days,
        'forward_hold_days': forward_hold_days,
        'modal': modal,
        'n_symbols': len(symbols)
    }
    cache_key = hashlib.sha256(json.dumps(cache_params, sort_keys=True).encode()).hexdigest()
    cache_file = 'backtest_results_parallel_vectorbt.pkl'

    # Cek cache
    if not force_refresh and os.path.exists(cache_file):
        try:
            with open(cache_file, 'rb') as f:
                cached = pickle.load(f)
            if cached.get('cache_key') == cache_key:
                print("✅ Memuat hasil backtest dari cache...")
                portfolio_returns = cached['portfolio_returns']
                dates = cached['dates']
                returns_series = pd.Series(portfolio_returns, index=dates)
                total_return = (1 + returns_series).prod() - 1
                n_years = (dates[-1] - dates[0]).days / 365.25 if len(dates) > 1 else 1
                cagr = (1 + total_return) ** (1/n_years) - 1 if n_years > 0 else 0
                sharpe = returns_series.mean() / returns_series.std() * np.sqrt(252/interval_days) if returns_series.std() > 0 else 0
                cum = (1 + returns_series).cumprod()
                max_dd = (cum / cum.expanding().max() - 1).min()
                win_rate = (returns_series > 0).mean() * 100
                profit_factor = returns_series[returns_series>0].sum() / abs(returns_series[returns_series<0].sum()) if returns_series[returns_series<0].sum() != 0 else np.inf
                print("\n" + "="*80)
                print("📊 HASIL BACKTEST")
                print("="*80)
                print(f"Jumlah periode: {len(dates)}")
                print(f"Total Return: {total_return:.2%}")
                print(f"CAGR: {cagr:.2%}")
                print(f"Sharpe Ratio (annualized): {sharpe:.2f}")
                print(f"Max Drawdown: {max_dd:.2%}")
                print(f"Win Rate: {win_rate:.1f}%")
                print(f"Profit Factor: {profit_factor:.2f}")
                print("="*80)
                try:
                    plt.figure(figsize=(12, 6))
                    equity = modal * (1 + returns_series).cumprod()
                    plt.plot(dates, equity, color='blue', linewidth=2, label='Equity')
                    plt.fill_between(dates, modal, equity, where=(equity >= modal), color='green', alpha=0.3, label='Profit')
                    plt.fill_between(dates, modal, equity, where=(equity < modal), color='red', alpha=0.3, label='Loss')
                    plt.axhline(y=modal, color='black', linestyle='--', linewidth=1, label='Initial Modal')
                    plt.title(f'Equity Curve (Backtest {start_date.date()} to {end_date.date()})\nCAGR: {cagr:.2%} | Max DD: {max_dd:.2%}')
                    plt.xlabel('Date')
                    plt.ylabel('Modal (Rp)')
                    plt.legend()
                    plt.grid(True, alpha=0.3)
                    plt.tight_layout()
                    plt.savefig('equity_curve_parallel_vectorbt.png', dpi=100)
                    print("📈 Equity curve saved as 'equity_curve_parallel_vectorbt.png'")
                    plt.show()
                except Exception as e:
                    print(f"⚠️ Gagal membuat plot equity curve: {e}")
                return
        except Exception as e:
            print(f"⚠️ Gagal memuat cache: {e}")

    print("\n🔄 Menjalankan backtest paralel per periode...")

    # Load semua data harga sekali
    all_price_data = {}
    for sym in symbols:
        df = warehouse.get_data(sym)
        if df is not None and len(df) > 0:
            all_price_data[sym] = df
    if not all_price_data:
        print("❌ Tidak ada data harga.")
        return

    global_fetcher = GlobalIndicesFetcher()
    global_fetcher.fetch_all()

    ref_symbol = next(iter(all_price_data.keys()))
    ref_df = all_price_data[ref_symbol].sort_index()
    mask = (ref_df.index >= start_date) & (ref_df.index <= end_date)
    candidate_dates = ref_df.index[mask][::interval_days]
    candidate_dates = [d for d in candidate_dates if (d + pd.Timedelta(days=forward_hold_days)) <= ref_df.index[-1]]
    print(f"Jumlah periode scanning: {len(candidate_dates)}")

    # ========== FUNGSI UNTUK MEMPROSES SATU PERIODE ==========
    from joblib import Parallel, delayed
    import functools
    import vectorbt as vbt

    def process_stock_signal_backtest(symbol, price_data, global_fetcher, config, modal, vol_mult):
        """Memproses satu saham untuk scanning (digunakan paralel di dalam periode)"""
        df = price_data.get(symbol)
        if df is None or len(df) < 200:
            return None
        risk_mgr_local = RiskManager(modal=modal, engine_type='swing')
        risk_mgr_local.risk_per_trade_pct = 1.0 * vol_mult
        risk_mgr_local.risk_per_trade_rp = modal * (risk_mgr_local.risk_per_trade_pct / 100)
        swing_engine = SwingEngine(config, global_fetcher)
        swing_engine.set_risk_manager(risk_mgr_local)
        fgv_engine = FGVEngine(config, global_fetcher)
        fgv_engine.set_risk_manager(risk_mgr_local)
        signals = []
        sig = swing_engine.get_signal(symbol, df)
        if sig:
            signals.append(sig)
        sig2 = fgv_engine.get_signal(symbol, df)
        if sig2:
            signals.append(sig2)
        return signals if signals else None

    def process_advanced_backtest(signal, price_data):
        """Memproses advanced models untuk satu sinyal (digunakan paralel di dalam periode)"""
        sym = signal['Symbol']
        df = price_data.get(sym)
        if df is None or len(df) < 200:
            return signal
        proc = AdvancedSignalProcessor()
        proc.fit_models(df)
        enhanced = proc.process_signal(df, signal)
        return enhanced if enhanced is not None else signal

    def simulate_portfolio_vectorbt(selected, all_price_data, current_date, forward_hold_days, modal):
        """Menggunakan VectorBT untuk simulasi portofolio periode ini"""
        if not selected:
            return None

        # Siapkan data harga untuk saham yang terpilih
        selected_symbols = [pos['Symbol'] for pos in selected]
        price_data_selected = {}
        for sym in selected_symbols:
            df = all_price_data.get(sym)
            if df is not None:
                future_slice = df[(df.index > current_date) & (df.index <= current_date + pd.Timedelta(days=forward_hold_days))]
                if len(future_slice) > 0:
                    price_data_selected[sym] = future_slice['Close']

        if not price_data_selected:
            return None

        # Buat DataFrame harga
        price_df = pd.DataFrame(price_data_selected)
        price_df = price_df.dropna()
        if len(price_df) == 0:
            return None

        # Buat entry dan exit signals (sederhana, karena partial exit rumit untuk VectorBT)
        entries = pd.DataFrame(index=price_df.index, columns=price_df.columns, dtype=bool)
        exits = pd.DataFrame(index=price_df.index, columns=price_df.columns, dtype=bool)

        for pos in selected:
            sym = pos['Symbol']
            if sym not in price_df.columns:
                continue
            entry_price = pos['Signal_Price']
            exit_plan = pos.get('Exit_Plan', None)
            is_sideways = pos.get('Is_Sideways', False)
            signal_type = pos.get('Signal_Type', 'BULLISH')

            # Entry di hari pertama
            entries.loc[price_df.index[0], sym] = True

            if is_sideways or exit_plan is None:
                sl = pos['Stop_Loss']
                tp = pos['Take_Profit']
                # Exit jika mencapai SL atau TP
                for date in price_df.index:
                    price = price_df.loc[date, sym]
                    if signal_type == 'BULLISH':
                        if price >= tp or price <= sl:
                            exits.loc[date, sym] = True
                            break
                    else:
                        if price <= tp or price >= sl:
                            exits.loc[date, sym] = True
                            break
                else:
                    # Jika tidak pernah kena SL/TP, exit di akhir periode
                    exits.loc[price_df.index[-1], sym] = True
            else:
                # Untuk partial exit + trailing stop, kita sederhanakan: exit di akhir periode
                # atau gunakan trailing stop sederhana
                # Cari trailing stop
                trailing_activated = False
                highest = entry_price
                for date in price_df.index:
                    price = price_df.loc[date, sym]
                    if price > highest:
                        highest = price
                    if not trailing_activated and price >= exit_plan['trailing']['activation_price']:
                        trailing_activated = True
                    if trailing_activated:
                        trail_stop = highest - (exit_plan['trailing']['distance_mult'] * pos['ATR'])
                        if price <= trail_stop:
                            exits.loc[date, sym] = True
                            break
                else:
                    exits.loc[price_df.index[-1], sym] = True

        entries = entries.fillna(False)
        exits = exits.fillna(False)

        # Siapkan size (jumlah lot * 100 lembar)
        size = pd.Series(index=price_df.columns, dtype=float)
        for pos in selected:
            sym = pos['Symbol']
            if sym in size.index:
                size[sym] = pos['Lot'] * 100

        # Buat size array sesuai entries
        size_array = pd.DataFrame(0.0, index=entries.index, columns=entries.columns)
        for sym in entries.columns:
            if sym in size:
                size_array[sym] = size[sym]

        try:
            # Inisialisasi portfolio VectorBT
            pf = vbt.Portfolio.from_signals(
                price_df,
                entries,
                exits,
                init_cash=modal,
                size=size_array,
                freq='D',
                fees=0.001  # 0.1% fee
            )
            # Return total return sebagai desimal (misal 0.05 untuk 5%)
            total_return = pf.total_return()
            return total_return
        except Exception as e:
            # Fallback ke perhitungan manual jika VectorBT error
            # (kode fallback seperti sebelumnya)
            return None

    def process_single_period(current_date, all_price_data, global_fetcher, modal, forward_hold_days):
        """Memproses satu periode scanning secara independen"""
        # Potong data hingga current_date
        current_data = {}
        for sym, df in all_price_data.items():
            df_cut = df[df.index <= current_date].copy()
            if len(df_cut) >= 200:
                current_data[sym] = df_cut
        if not current_data:
            return None

        # Volatility scaling
        ihsg_hist = global_fetcher.data.get('IHSG')
        vol_mult = 1.0
        if ihsg_hist is not None and len(ihsg_hist) > 50:
            ihsg_cut = ihsg_hist[ihsg_hist.index <= current_date]
            if len(ihsg_cut) > 50:
                high = ihsg_cut['High']
                low = ihsg_cut['Low']
                close = ihsg_cut['Close']
                tr = high - low
                atr = tr.rolling(14).mean().iloc[-1]
                current_price = close.iloc[-1]
                atr_pct = (atr / current_price) * 100
                if atr_pct > 2.0:
                    vol_mult = 0.5
                elif atr_pct > 1.2:
                    vol_mult = 0.7

        config = type('Config', (), {'MODAL': modal})()
        risk_manager = RiskManager(modal=modal, engine_type='swing')
        risk_manager.risk_per_trade_pct = 1.0 * vol_mult
        risk_manager.risk_per_trade_rp = modal * (risk_manager.risk_per_trade_pct / 100)

        # ========== PARALEL SCANNING DI DALAM PERIODE ==========
        func_scan = functools.partial(process_stock_signal_backtest, price_data=current_data,
                                      global_fetcher=global_fetcher, config=config,
                                      modal=modal, vol_mult=vol_mult)
        # Gunakan paralel di dalam periode juga
        results = Parallel(n_jobs=-1, verbose=0)(delayed(func_scan)(sym) for sym in current_data.keys())
        all_signals = []
        for res in results:
            if res:
                all_signals.extend(res)

        if not all_signals:
            return None

        # ========== PARALEL ADVANCED PROCESSING ==========
        enhanced_signals = Parallel(n_jobs=-1, verbose=0)(
            delayed(process_advanced_backtest)(sig, current_data) for sig in all_signals
        )
        enhanced_signals = [s for s in enhanced_signals if s is not None]
        if not enhanced_signals:
            return None

        # ========== PORTFOLIO BUILDER (serial karena state) ==========
        builder = PortfolioBuilder(modal=modal, max_positions=10, max_correlation=0.7, max_per_sector=2)
        risk_manager.reset()
        selected = builder.build(enhanced_signals, current_data, risk_manager)
        if not selected:
            return None

        # ========== SIMULASI DENGAN VECTORBT ==========
        period_return = simulate_portfolio_vectorbt(selected, all_price_data, current_date, forward_hold_days, modal)
        if period_return is None:
            # Fallback ke perhitungan manual sederhana jika VectorBT gagal
            total_portfolio_return = 0.0
            total_portfolio_risk = sum(p['Risk_Amount'] for p in selected)
            if total_portfolio_risk == 0:
                return None
            for pos in selected:
                sym = pos['Symbol']
                entry_price = pos['Signal_Price']
                lot = pos['Lot']
                risk_amount = pos['Risk_Amount']
                weight = risk_amount / total_portfolio_risk
                exit_plan = pos.get('Exit_Plan', None)
                is_sideways = pos.get('Is_Sideways', False)
                signal_type = pos.get('Signal_Type', 'BULLISH')

                df_future = all_price_data.get(sym)
                if df_future is None:
                    continue
                future_slice = df_future[(df_future.index > current_date) & (df_future.index <= current_date + pd.Timedelta(days=forward_hold_days))]
                if len(future_slice) == 0:
                    continue

                if is_sideways or exit_plan is None:
                    sl = pos['Stop_Loss']
                    tp = pos['Take_Profit']
                    exit_price = None
                    if signal_type == 'BULLISH':
                        for _, row in future_slice.iterrows():
                            if row['High'] >= tp:
                                exit_price = tp
                                break
                            if row['Low'] <= sl:
                                exit_price = sl
                                break
                        if exit_price is None:
                            exit_price = future_slice['Close'].iloc[-1]
                        ret = (exit_price - entry_price) / entry_price
                    else:
                        for _, row in future_slice.iterrows():
                            if row['Low'] <= tp:
                                exit_price = tp
                                break
                            if row['High'] >= sl:
                                exit_price = sl
                                break
                        if exit_price is None:
                            exit_price = future_slice['Close'].iloc[-1]
                        ret = (entry_price - exit_price) / entry_price
                    total_portfolio_return += weight * ret
                else:
                    # Partial exit + trailing stop
                    remaining_lot = lot
                    realized_pnl = 0.0
                    highest_high = entry_price
                    trailing_active = False
                    for lvl in exit_plan['levels']:
                        lvl['executed'] = False
                    for _, row in future_slice.iterrows():
                        high = row['High']
                        low = row['Low']
                        close_price = row['Close']
                        if high > highest_high:
                            highest_high = high
                        atr = pos['ATR']
                        # Partial TP
                        for lvl in exit_plan['levels']:
                            if lvl.get('executed', False):
                                continue
                            if high >= lvl['price']:
                                sell_lot = int(round(lot * lvl['sell_pct'] / 100))
                                if sell_lot > 0 and sell_lot <= remaining_lot:
                                    profit = (lvl['price'] - entry_price) / entry_price
                                    realized_pnl += profit * (sell_lot / lot)
                                    remaining_lot -= sell_lot
                                    lvl['executed'] = True
                        # Trailing stop
                        if remaining_lot > 0 and 'trailing' in exit_plan:
                            if not trailing_active and high >= exit_plan['trailing']['activation_price']:
                                trailing_active = True
                            if trailing_active:
                                trail_stop = highest_high - (exit_plan['trailing']['distance_mult'] * atr)
                                trail_stop = max(trail_stop, pos['Stop_Loss'])
                                fraction = 5 if close_price < 100 else 10 if close_price < 500 else 25
                                trail_stop = math.floor(trail_stop / fraction) * fraction
                                if low <= trail_stop:
                                    profit = (trail_stop - entry_price) / entry_price
                                    realized_pnl += profit * (remaining_lot / lot)
                                    remaining_lot = 0
                                    break
                    if remaining_lot > 0:
                        exit_price = future_slice['Close'].iloc[-1]
                        profit = (exit_price - entry_price) / entry_price
                        realized_pnl += profit * (remaining_lot / lot)
                    total_portfolio_return += weight * realized_pnl
            period_return = total_portfolio_return

        return period_return

    # ========== EKSEKUSI PARALEL UNTUK SEMUA PERIODE ==========
    print("Memproses semua periode secara paralel...")
    # Batasi jumlah proses jika perlu (misal n_jobs=4 untuk menghindari memory overload)
    n_jobs = -1  # Gunakan semua core
    # Jika sering memory error, ganti dengan n_jobs = 4
    results = Parallel(n_jobs=n_jobs, verbose=10)(
        delayed(process_single_period)(current_date, all_price_data, global_fetcher, modal, forward_hold_days)
        for current_date in candidate_dates
    )

    # Kumpulkan hasil
    dates = []
    portfolio_returns = []
    for idx, ret in enumerate(results):
        if ret is not None:
            dates.append(candidate_dates[idx])
            portfolio_returns.append(ret)

    if not portfolio_returns:
        print("❌ Tidak ada return yang dihasilkan.")
        return

    # Simpan ke cache
    cache_data = {
        'cache_key': cache_key,
        'dates': dates,
        'portfolio_returns': portfolio_returns,
        'params': cache_params
    }
    try:
        with open(cache_file, 'wb') as f:
            pickle.dump(cache_data, f)
        print(f"✅ Hasil backtest disimpan ke {cache_file}")
    except Exception as e:
        print(f"⚠️ Gagal menyimpan cache: {e}")

    # Hitung metrik
    returns_series = pd.Series(portfolio_returns, index=dates)
    total_return = (1 + returns_series).prod() - 1
    n_years = (dates[-1] - dates[0]).days / 365.25 if len(dates) > 1 else 1
    cagr = (1 + total_return) ** (1/n_years) - 1 if n_years > 0 else 0
    sharpe = returns_series.mean() / returns_series.std() * np.sqrt(252/interval_days) if returns_series.std() > 0 else 0
    cum = (1 + returns_series).cumprod()
    max_dd = (cum / cum.expanding().max() - 1).min()
    win_rate = (returns_series > 0).mean() * 100
    profit_factor = returns_series[returns_series>0].sum() / abs(returns_series[returns_series<0].sum()) if returns_series[returns_series<0].sum() != 0 else np.inf

    print("\n" + "="*80)
    print("📊 HASIL BACKTEST")
    print("="*80)
    print(f"Jumlah periode: {len(dates)}")
    print(f"Total Return: {total_return:.2%}")
    print(f"CAGR: {cagr:.2%}")
    print(f"Sharpe Ratio (annualized): {sharpe:.2f}")
    print(f"Max Drawdown: {max_dd:.2%}")
    print(f"Win Rate: {win_rate:.1f}%")
    print(f"Profit Factor: {profit_factor:.2f}")
    print("="*80)

    # Plot equity curve
    try:
        plt.figure(figsize=(12, 6))
        equity = modal * (1 + returns_series).cumprod()
        plt.plot(dates, equity, color='blue', linewidth=2, label='Equity')
        plt.fill_between(dates, modal, equity, where=(equity >= modal), color='green', alpha=0.3, label='Profit')
        plt.fill_between(dates, modal, equity, where=(equity < modal), color='red', alpha=0.3, label='Loss')
        plt.axhline(y=modal, color='black', linestyle='--', linewidth=1, label='Initial Modal')
        plt.title(f'Equity Curve (Backtest {start_date.date()} to {end_date.date()})\nCAGR: {cagr:.2%} | Max DD: {max_dd:.2%}')
        plt.xlabel('Date')
        plt.ylabel('Modal (Rp)')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig('equity_curve_parallel_vectorbt.png', dpi=100)
        print("📈 Equity curve saved as 'equity_curve_parallel_vectorbt.png'")
        plt.show()
    except Exception as e:
        print(f"⚠️ Gagal membuat plot equity curve: {e}")

# =============================================================================
# 24. WALK-FORWARD COLLECTOR (UNTUK VALIDASI OOS, TIDAK UNTUK LIVE)
# =============================================================================
class WalkForwardCollector:
    def __init__(self, warehouse, collection_dir='backtest_collection'):
        self.warehouse = warehouse
        self.collection_dir = collection_dir
        os.makedirs(collection_dir, exist_ok=True)
        self.trades_cache = defaultdict(list)

    def collect_for_engine(self, engine, engine_type: str, symbols: list, years_back: int = 5, sample_frequency: int = 10):
        print(f"\n📥 Collecting {engine_type} historical signals...")
        # Implementasi sederhana: hanya placeholder
        return {'total_trades': 0, 'symbols_with_data': 0}

    def get_engine_returns_series(self, engine_type: str) -> pd.Series:
        return pd.Series(dtype=float)

# =============================================================================
# 25. INISIALISASI DATA WAREHOUSE
# =============================================================================
def initialize_data_warehouse():
    print("\n" + "="*80)
    print("🗄️ INISIALISASI DATA WAREHOUSE")
    print("="*80)
    warehouse = DataWarehouse(warehouse_dir='data_warehouse', min_days=1000)
    existing = warehouse.get_all_valid_symbols()
    print(f"Data harga yang sudah tersedia: {len(existing)} saham")
    confirm = input("\nDownload data harga untuk semua saham? (y/n): ").strip().lower()
    if confirm == 'y':
        print("\n⚠️ Proses download akan memakan waktu beberapa jam.")
        confirm2 = input("Lanjutkan? (y/n): ").strip().lower()
        if confirm2 == 'y':
            warehouse.download_complete_history(symbols=STOCKBIT_UNIVERSE, start_date='2006-01-01', end_date='2026-12-31')
            print("✅ Selesai.")
        else:
            print("⏩ Lewati.")
    else:
        print("⏩ Lewati.")
    print(f"Total saham valid: {len(warehouse.get_all_valid_symbols())}")

# =============================================================================
# 26. PHASE 1 - SCANNER (JALANKAN SEMUA ENGINE)
# =============================================================================
from joblib import Parallel, delayed
import functools

def process_stock_signals(symbol, price_data, global_fetcher, config, modal, vol_mult, engine_type='swing'):
    """
    Memproses satu saham untuk mendapatkan sinyal dari Swing atau FGV engine.
    Fungsi ini independen, tidak mengubah state global.
    """
    df = price_data.get(symbol)
    if df is None or len(df) < 200:
        return None

    # Inisialisasi risk manager lokal (tidak shared)
    risk_manager = RiskManager(modal=modal, engine_type=engine_type)
    risk_manager.set_risk_multiplier(vol_mult)

    signals = []

    # Swing engine
    swing_engine = SwingEngine(config, global_fetcher)
    swing_engine.set_risk_manager(risk_manager)
    sig = swing_engine.get_signal(symbol, df)
    if sig:
        signals.append(sig)

    # FGV engine
    fgv_engine = FGVEngine(config, global_fetcher)
    fgv_engine.set_risk_manager(risk_manager)
    sig2 = fgv_engine.get_signal(symbol, df)
    if sig2:
        signals.append(sig2)

    return signals if signals else None

def process_advanced_single(signal, price_data, advanced_processor):
    """
    Memproses satu sinyal dengan advanced models.
    advanced_processor adalah objek yang sudah di-fit (atau akan di-fit per saham).
    Karena advanced_processor memiliki state internal, kita perlu berhati-hati.
    Alternatif: buat advanced_processor baru untuk setiap sinyal.
    """
    sym = signal['Symbol']
    df = price_data.get(sym)
    if df is None or len(df) < 200:
        return signal  # return original if no data

    # Buat processor baru untuk menghindari race condition
    proc = AdvancedSignalProcessor()
    proc.fit_models(df)
    enhanced = proc.process_signal(df, signal)
    return enhanced if enhanced is not None else signal

def run_phase1(sheets_exporter, modal=None):
    """
    Phase 1 - Trading Scanner dengan paralelisasi menggunakan joblib
    """
    print("\n" + "="*60)
    print("🏦 IDX STOCK SCANNER - Medallion Style (Swing + FGV)")
    print("="*60)

    warehouse = DataWarehouse(warehouse_dir='data_warehouse', min_days=400)
    symbols = warehouse.get_all_valid_symbols()
    if not symbols:
        print("⚠️ Data warehouse kosong. Jalankan inisialisasi terlebih dahulu.")
        return
    print(f"\n📊 Data warehouse: {len(symbols)} saham valid")

    if modal is None:
        while True:
            try:
                modal_input = input("Modal total (Rp): ").strip()
                modal = int(modal_input.replace('.', '').replace(',', ''))
                if modal >= 10000:
                    break
                print("Minimal Rp 10,000")
            except:
                print("Input tidak valid")

    # Global fetcher
    global_fetcher = GlobalIndicesFetcher()
    global_fetcher.fetch_all()

    # Volatility scaling
    ihsg_df = global_fetcher.data.get('IHSG')
    vol_mult = 1.0
    if ihsg_df is not None and len(ihsg_df) > 50:
        try:
            high = ihsg_df['High']
            low = ihsg_df['Low']
            close = ihsg_df['Close']
            tr = high - low
            atr = tr.rolling(14).mean().iloc[-1]
            current_price = close.iloc[-1]
            atr_pct = (atr / current_price) * 100
            if atr_pct > 2.0:
                vol_mult = 0.5
            elif atr_pct > 1.2:
                vol_mult = 0.7
            print(f"\n📈 Volatilitas IHSG: {atr_pct:.2f}% -> multiplier {vol_mult:.1f}")
        except Exception as e:
            print(f"⚠️ Gagal hitung volatilitas IHSG: {e}")

    # Load price data
    print("\n🔍 Loading price data...")
    price_data = {}
    for sym in symbols:
        df = warehouse.get_data(sym)
        if df is not None:
            price_data[sym] = df
    print(f"   Loaded {len(price_data)} saham")

    config = type('Config', (), {'MODAL': modal})()

    # ========== PARALLEL SCANNING ==========
    print("\n🔍 Scanning Swing & FGV engines in parallel...")

    from joblib import Parallel, delayed
    import functools

    def process_stock(symbol, price_data, global_fetcher, config, modal, vol_mult):
        df = price_data.get(symbol)
        if df is None or len(df) < 200:
            return None
        risk_manager = RiskManager(modal=modal, engine_type='swing')
        risk_manager.set_risk_multiplier(vol_mult)
        signals = []
        # Swing
        swing_engine = SwingEngine(config, global_fetcher)
        swing_engine.set_risk_manager(risk_manager)
        sig = swing_engine.get_signal(symbol, df)
        if sig:
            signals.append(sig)
        # FGV
        fgv_engine = FGVEngine(config, global_fetcher)
        fgv_engine.set_risk_manager(risk_manager)
        sig2 = fgv_engine.get_signal(symbol, df)
        if sig2:
            signals.append(sig2)
        return signals if signals else None

    func = functools.partial(process_stock, price_data=price_data, global_fetcher=global_fetcher,
                             config=config, modal=modal, vol_mult=vol_mult)
    results = Parallel(n_jobs=-1, verbose=0)(delayed(func)(sym) for sym in symbols)

    all_signals = []
    for res in results:
        if res:
            all_signals.extend(res)

    swing_count = sum(1 for s in all_signals if s['Engine'] == 'SWING')
    fgv_count = sum(1 for s in all_signals if s['Engine'] == 'FGV')
    print(f"   Swing signals: {swing_count}")
    print(f"   FGV signals: {fgv_count}")

    if not all_signals:
        print("\n❌ Tidak ada sinyal hari ini.")
        return

    # ========== ADVANCED PROCESSING PARALLEL ==========
    print("\n🧠 Processing signals through advanced quant models in parallel...")

    def process_advanced(signal, price_data):
        sym = signal['Symbol']
        df = price_data.get(sym)
        if df is None or len(df) < 200:
            return signal
        proc = AdvancedSignalProcessor()
        proc.fit_models(df)
        enhanced = proc.process_signal(df, signal)
        return enhanced if enhanced is not None else signal

    enhanced_signals = Parallel(n_jobs=-1, verbose=0)(delayed(process_advanced)(sig, price_data) for sig in all_signals)
    enhanced_signals = [s for s in enhanced_signals if s is not None]
    print(f"   Signals after advanced filtering: {len(enhanced_signals)}")

    if not enhanced_signals:
        print("\n❌ Tidak ada sinyal setelah advanced filtering.")
        return

    # ========== PORTFOLIO BUILDER ==========
    risk_manager = RiskManager(modal=modal, engine_type='swing')
    risk_manager.set_risk_multiplier(vol_mult)
    builder = PortfolioBuilder(modal=modal, max_positions=10, max_correlation=0.7, max_per_sector=2)
    risk_manager.reset()
    selected = builder.build(enhanced_signals, price_data, risk_manager)

    if not selected:
        print("\n❌ Tidak ada sinyal yang lolos portfolio builder.")
        return

    # Display
    print("\n" + "="*140)
    print("📊 PORTFOLIO DASHBOARD (Enhanced with Advanced Models)")
    print("="*140)
    print(f"{'Engine':4} | {'Symbol':6} | {'Sector':15} | {'Price':6} | {'SL':5} | {'TP':6} | {'Lot':3} | {'R/R':4} | {'EV%':5} | {'AdvConf%':6} | {'AdvComp':6} | {'Risk%':5}")
    print("-"*140)
    for s in selected:
        conf_display = s.get('Advanced_Confidence', s.get('Confidence_Score', 0))
        comp_display = s.get('Advanced_Composite', s.get('Composite_Score', 0))
        print(f"{s['Engine']:4} | {s['Symbol']:6} | {s['Sector']:15} | {s['Signal_Price']:6} | {s['Stop_Loss']:5} | {s['Take_Profit']:6} | {s['Lot']:3} | {s['R/R']:.2f} | {s['EV_Pct']:.2f} | {conf_display:.0f} | {comp_display:.1f} | {s['Risk_Pct']:.1f}")

    total_cost = sum(s['Cost'] for s in selected)
    total_risk = sum(s['Risk_Amount'] for s in selected)
    print("\n" + "-"*80)
    print(f"Total Modal: Rp {modal:,.0f} | Total Cost: Rp {total_cost:,.0f} ({total_cost/modal*100:.1f}%) | Total Risk: Rp {total_risk:,.0f} ({total_risk/modal*100:.1f}%) | Risk Budget Used: {risk_manager.get_portfolio_risk_pct():.1f}%")
    risk_manager.print_display()

    # Export & charts
    export = input("\n📊 Export ke Google Sheets? (y/n): ").strip().lower()
    if export == 'y':
        sheets_exporter.ensure_spreadsheet_exists()
        sheets_exporter.export_signals([s for s in selected if s['Engine']=='SWING'], "SWING ENGINE", modal)
        sheets_exporter.export_signals([s for s in selected if s['Engine']=='FGV'], "FGV ENGINE", modal)

    chart = input("\n📈 Generate chart untuk sinyal terpilih? (y/n): ").strip().lower()
    if chart == 'y':
        for s in selected:
            df = warehouse.get_data(s['Symbol'])
            if df is not None:
                generate_signal_chart(s, df, s['Engine'].lower())

# =============================================================================
# 27. MAIN MENU
# =============================================================================
def main():
    print("\n" + "="*70)
    print("🏦 IDX STOCK SCANNER - Medallion Style (Swing + FGV + Advanced Quant)")
    print("="*70)
    sheets_exporter = GoogleSheetsExporter()
    sheets_exporter.ensure_spreadsheet_exists()
    print("\nPilih Mode:")
    print("1. Inisialisasi Data Warehouse")
    print("2. Phase 1 - Trading Scanner (Jalankan Semua Engine + Advanced Models)")
    print("3. System Quality Dashboard (Backtest End-to-End)")
    print("4. Exit")

    while True:
        choice = input("\nPilihan (1/2/3/4): ").strip()
        if choice == '1':
            initialize_data_warehouse()
            break
        elif choice == '2':
            run_phase1(sheets_exporter)
            break
        elif choice == '3':
            run_system_backtest()
            break
        elif choice == '4':
            print("\n✅ Exiting...")
            break
        else:
            print("❌ Pilih 1,2,3 atau 4")

if __name__ == "__main__":
    main()
# Out:
# ✅ Dependencies imported
#
# ======================================================================
# 🏦 IDX STOCK SCANNER - Medallion Style (Swing + FGV + Advanced Quant)
# ======================================================================
# ✅ Berhasil konek ke Google Sheets
#
# 📊 Google Sheets URL: https://docs.google.com/spreadsheets/d/17vhCnEIA_p_7obIODa7hPx4OIs-6slK9dsckpKK9MoA
#
# Pilih Mode:
# 1. Inisialisasi Data Warehouse
# 2. Phase 1 - Trading Scanner (Jalankan Semua Engine + Advanced Models)
# 3. System Quality Dashboard (Backtest End-to-End)
# 4. Exit
#
# ================================================================================
# 📊 SYSTEM QUALITY DASHBOARD (End-to-End Backtest) - PARALLEL PER PERIODE + VECTORBT
# ================================================================================
# Periode: 2006-04-10 - 2026-04-05 | Saham: 588
# Interval scanning: setiap 20 hari | Holding: 10 hari | Modal simulasi: Rp 5,000,000
#
# 🔄 Menjalankan backtest paralel per periode...
#
# ================================================================================
# 📡 FETCHING GLOBAL INDICES
# ================================================================================
#
# 📊 IHSG: Indeks Harga Saham Gabungan (^JKSE)
#    ✅ Harga: 7,026.78
#
# 📊 DOWJONES: Dow Jones Industrial Average (^DJI)
#    ✅ Harga: 46,504.67
#
# 📊 USDIDR: USD/IDR (IDR=X)
#    ✅ Harga: Rp 17,010
#
# 📊 OIL: Crude Oil WTI (CL=F)
#    ✅ Harga: US$ 112.06
#
# 📊 GOLD: Gold Futures (GC=F)
#    ✅ Harga: US$ 4702.70
#
# 📊 NIKKEI: Nikkei 225 (^N225)
#    ✅ Harga: 53,123.49
#
# 📊 SHANGHAI: Shanghai Composite Index (000001.SS)
#    ✅ Harga: 3,880.10
#
# ================================================================================
# Jumlah periode scanning: 207
# Memproses semua periode secara paralel...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 37.3min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 64.9min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 102.8min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 152.3min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 214.7min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 318.2min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 423.4min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 544.0min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 686.4min
